# %% [markdown]
# # Import neo4j DB: 3/4
#
# Code to translate v2.7.4_PIS-model.xlsx to neo4j database.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import re
import numpy as np
import os
from IPython.display import Image

# %%
import helpers

# %%
from importlib import reload

# %% [markdown]
# Connect to graph via docker-compose link. See http://localhost:7474/browser/

# %%
from py2neo import Graph, Node, Relationship

# %%
graph = Graph(host="neo4j")

# %%
node_labels = [
    'PlantCoding',
    'PlantNonCoding',
    'PlantAbstract',
    'Complex',
    'ExternalOrganism', 
    'ExternalCoding',
    'ExternalNonCoding',
    'Process', 
    'MetaboliteFamily',
    'Metabolite',
    'Gene', 
    'Expression'
]

# %%
reaction_relationships = [
    'ACTIVATE',
    'SUBSTRATE',
    'INHIBIT',
    'PRODUCT',
    'TRANSLOCATE_FROM',
    'TRANSLOCATE_TO'
]

# %% [markdown]
# ## Read in sheets

# %%
input_path = os.path.join("..", "data", "raw")

# %%
sheets = [#(file, sheet_name)]
    ("v2.7.5_PIS-model.xlsx", "Reactions"),
    ("v2.7.5_PIS-model.xlsx", "Reactions_New"), 
    ("Model_CK.xlsx", "Reactions_new"), 
    ("v2.7.2_PIS-model-JALR.xlsx", "Reactions_New")
]

# %%
# resave xlsx as tsv
drops = ['Status', 'FOXMES', 'Legacy:Process', 'Legacy:ReactionMode']#, 'ConnID']
col_rename = {
    'AddedBy':'AddedBy',
    'Species':'Species',
    'ID':'input1_ID',
    'level':'input1_level',
    'localisation':'input1_localisation',
    'type':'input1_type',
    'ID.1':'input2_ID',
    'level.1':'input2_level',
    'localisation.1':'input2_localisation',
    'type.1':'input2_type',
    'ID.2':'input3_ID',
    'level.2':'input3_level',
    'localisation.2':'input3_localisation',
    'type.2':'input3_type',
    'ReactionEffect':'ReactionEffect',
    'ReactionMode':'ReactionMode',
    'Modifications':'Modifications',
    'ID.3':'output1_ID',
    'level.3':'output1_level',
    'localisation.3':'output1_localisation',
    'type.3':'output1_type',
    'TrustLevel':'TrustLevel',
    'Literature':'Literature',
    'AdditionalInfo':'AdditionalInfo',
    'Comment':'Comment',
    'Model-v':'ModelV',
    'KINETICS':'kinetics', 
    'ConnID': 'ConnID'
}

for file_name, sheet_name in sheets:
    
    print(file_name, sheet_name)
    
    file_path = os.path.join(input_path, file_name)
    
    base_name, extension = os.path.splitext(file_name)
    new_file_path = os.path.join(input_path, f'{base_name}-{sheet_name}.tsv')
    
     if os.path.exists(new_file_path):
        continue
        
    df = pd.read_excel(file_path, 
                    sheet_name=sheet_name, 
                    header=[1], 
                    dtype=str, 
                    na_values=helpers.empty_strings)

    df = df[~df["AddedBy"].isna()]
    
    if 'Status' in df.columns:
        df = df[df['Status'].isin(["forCB", "forCB_INVENTED", np.nan])]

    to_drop = list(set(drops) & set(df.columns)) + list(df.filter(regex=("Unnamed.*")).columns)
    df.drop(to_drop, axis=1, inplace=True)
    
    new_cols = [col_rename[x] for x in df.columns]
    df.columns = new_cols
    
    df['origin'] = f'{base_name}-{sheet_name}'
    
    df.to_csv(new_file_path, sep="\t", index=None)
# Out:
# v2.7.5_PIS-model.xlsx Reactions
# v2.7.5_PIS-model.xlsx Reactions_New
# Model_CK.xlsx Reactions_new
# v2.7.2_PIS-model-JALR.xlsx Reactions_New

# %%
dfs = []

for file_name, sheet_name in sheets:
    
    print(file_name, sheet_name)
    base_name, extension = os.path.splitext(file_name)

    file_path = os.path.join(input_path, f'{base_name}-{sheet_name}.tsv')
    
    df = pd.read_csv(file_path, sep="\t")

    dfs.append(df)
# Out:
# v2.7.5_PIS-model.xlsx Reactions
# v2.7.5_PIS-model.xlsx Reactions_New
# Model_CK.xlsx Reactions_new
# v2.7.2_PIS-model-JALR.xlsx Reactions_New

# %%
df_edges = pd.concat(dfs, sort=False)
df_edges.reset_index(drop=True, inplace=True)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ... output1_level  \
# 0  metabolite      SAMS        clade                  ER  ...        family
# 1  metabolite       ACS       family                  ER  ...        family
# 2  metabolite       ACO       family                  ER  ...        family
# 3  metabolite       HMA       family                  ER  ...        family
# 4     protein      Cu2+       family                  ER  ...        family
#
#   output1_localisation      output1_type  \
# 0                   ER        metabolite
# 1                   ER        metabolite
# 2                   ER        metabolite
# 3                   ER        metabolite
# 4                   ER  protein [active]
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.     NaN   v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.     NaN   v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.     NaN   v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...     NaN   v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...     NaN   v1.0      NaN
#
#                        origin
# 0  v2.7.5_PIS-model-Reactions
# 1  v2.7.5_PIS-model-Reactions
# 2  v2.7.5_PIS-model-Reactions
# 3  v2.7.5_PIS-model-Reactions
# 4  v2.7.5_PIS-model-Reactions
#
# [5 rows x 29 columns]

# %%
x = df_edges[df_edges['AddedBy']=='x'].index
print(x)
df_edges.drop(x, inplace=True)
# Out:
# Int64Index([], dtype='int64')

# %%
df_edges["TrustLevel"].unique()
# Out:
# array(['[R1] targetted experiments (e.g. Y2H, BIFC)',
#        '[Ry] invented reaction', '[Rx] incomplete/unspecific reaction',
#        '[R2] high-throughput experiment (e.g. ChIP-seq)',
#        '[R3] in-silico prediction', '[R4] indirect reaction'],
#       dtype=object)

# %%
df_edges['trust_level']  = df_edges["TrustLevel"].apply(lambda x: re.search( r"(R[1|2|3|4|x|y]|undefined)", x).groups()[0])
df_edges['observed_species'] = df_edges['Species'].apply(helpers.lower_string)
df_edges['species_also_observed_in'] = df_edges["Species"].apply(helpers.rest_of_items)
df_edges['Comment'] = df_edges['Comment'].fillna("")
df_edges['AdditionalInfo'] = df_edges['AdditionalInfo'].fillna("")

# %%
df_edges['AddedBy'] = df_edges['AddedBy'].apply(lambda x: x.upper())
df_edges["AddedBy"].unique()
# Out:
# array(['KG', 'MZ', 'ZR', 'MPE', 'ACR', 'MAK', 'ST', 'SB', 'AG', 'JALR'],
#       dtype=object)

# %%
df_edges.loc[df_edges['ModelV'].isna(), 'ModelV'] = 'vNA'
df_edges['ModelV'].unique()
# Out:
# array(['v1.0', 'v2.5', 'v2.7', 'v2.6', 'vNA'], dtype=object)

# %%
def get_non_ascii(x):
    x = str(x)
    has_nonascii = False
    for character in x:
        if not character.isascii():
            has_nonascii = True
            print(f"|{character}|", ord(character), character.encode())
    if has_nonascii:
        print(x)
        return True
    else:
        return False

ascii_replacers = {
    b'\xc2\xa0' : b" ",           # funky WIN whitespace
    b'\xe2\x80\xa6': b'...',      # …
    b'\xe2\x80\x8b' : b'',        # have no figging clue
    b'\xe2\x80\x93' : b'-',       # –
    b'\xce\xb1' : b"alpha",       # α
    b'\xc3\x9f' : b"beta",        # ß
    b'\xce\xb2' : b"beta",        # β
    b'\xe2\x80\x98' : b"prime",   # ‘
    b'\xe2\x80\x99' : b"prime",   # ’
    b'\xc2\xb4': b'prime',        # ´
    # Sorry accents :(
    b'\xc5\xa0' : b"S",           # Š
    b'\xc5\xa1' : b's',           # š
    b'\xc5\xbd' : b'Z',           # Ž
    b'\xc4\x8d' : b'c'            # č
}


def replacer(x):
    if not x in [' ', '', np.nan]:
        x = x.encode('utf-8')
        for old, new in ascii_replacers.items():
            x = x.replace(old, new)
        return x.decode('utf-8')
    return ''

# %%
bad_cols = []
for c in df_edges.columns:
    print(c, "\n-------------")
    if any(df_edges[c].apply(get_non_ascii)):
        bad_cols.append(c)
    print()
# Out:
# AddedBy
# -------------
# |Š| 352 b'\xc5\xa0'
# ŠT
#
# ConnID
# -------------
#
# Species
# -------------
#
# input1_ID
# -------------
# |´| 180 b'\xc2\xb4'
# 9-cis-b-apo-10´-carotenal
#
# input1_level
# -------------
#
# input1_localisation
# -------------
#
# input1_type
# -------------
#
# input2_ID
# -------------
#
# input2_level
# -------------
#
# input2_localisation
# -------------
#
# input2_type
# -------------
#
# input3_ID
# -------------
#
# input3_level
# -------------
#
# input3_localisation
# -------------
#
# input3_type
# -------------
#
# ReactionEffect
# -------------
#
# ReactionMode
# -------------
#
# Modifications
# -------------
#
# output1_ID
# -------------
# |´| 180 b'\xc2\xb4'
# 9-cis-b-apo-10´-carotenal
#
# output1_level
# -------------
#
# output1_localisation
# -------------
#
# output1_type
# -------------
#
# TrustLevel
# -------------
#
# Literature
# -------------
# |…| 8230 b'\xe2\x80\xa6'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1073/pnas.0605528103 (ETHYLENE-INSENSITIVE5 encodes…) | DOI:10.​1104/​pp.​107.​104299 (RTE1 Is a Golgi-Associated and ETR1-Dependent…)
# |…| 8230 b'\xe2\x80\xa6'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1073/pnas.0605528103 (ETHYLENE-INSENSITIVE5 encodes…) | DOI:10.​1104/​pp.​107.​104299 (RTE1 Is a Golgi-Associated and ETR1-Dependent…)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1073/pnas.0605528103 (ETHYLENE-INSENSITIVE5 encodes…) | DOI:10.1073/pnas.1214848109 (CTR1 phosphorylates the central regulator EIN2...) | DOI:10.1093/mp/ssq036 (New insight in ethylene signaling...) | DOI:10.1016/j.pbi.2008.06.011 (Ethylene signaling...) | DOI:10.1093/mp/ssr042 (Paradigms and paradox in the ethylene signaling...) | DOI:10.1042/BJ20091102 (EIN2, the central regulator of ethylene signalling...)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1073/pnas.0605528103 (ETHYLENE-INSENSITIVE5 encodes…) | DOI:10.1073/pnas.1214848109 (CTR1 phosphorylates the central regulator EIN2...) | DOI:10.1093/mp/ssq036 (New insight in ethylene signaling...) | DOI:10.1016/j.pbi.2008.06.011 (Ethylene signaling...) | DOI:10.1093/mp/ssr042 (Paradigms and paradox in the ethylene signaling...) | DOI:10.1042/BJ20091102 (EIN2, the central regulator of ethylene signalling...)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1073/pnas.0605528103 (ETHYLENE-INSENSITIVE5 encodes…) | DOI:10.1073/pnas.1214848109 (CTR1 phosphorylates the central regulator EIN2...) | DOI:10.1093/mp/ssq036 (New insight in ethylene signaling...) | DOI:10.1016/j.pbi.2008.06.011 (Ethylene signaling...) | DOI:10.1093/mp/ssr042 (Paradigms and paradox in the ethylene signaling...) | DOI:10.1042/BJ20091102 (EIN2, the central regulator of ethylene signalling...)
# |–| 8211 b'\xe2\x80\x93'
# DOI:10.1104/pp.106.095588 (Chen, 2007: Stability of Plant Defense Proteins...); DOI:10.1105/tpc.106.041103 Plant Cell. 2006 Nov; 18(11): 3303–3320.
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1126/scisignal.3109cm4 (Arabidopsis Jasmonate Signaling Pathway) | DOI:10.​1105/​tpc.​110.​080788 (The Arabidopsis bHLH Transcription Factors...) | DOI:10.1016/j.jtbi.2010.12.037 (Transient pulse formation...) | DOI:10.1146/annurev.arplant.043008.092007 (Jasmonate Passes Muster...) | DOI:10.1007/978-0-387-85498-4_8 (Regulation of Secondary Metabolism...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1111/j.1399-3054.2004.00418.x (Jasmonate-regulated Arabidopsis stress signalling network) | DOI:10.​1105/​tpc.​106.​048017 (MYC2 Differentially Modulates Diverse...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1111/j.1399-3054.2004.00418.x (Jasmonate-regulated Arabidopsis stress signalling network) | DOI:10.​1105/​tpc.​106.​048017 (MYC2 Differentially Modulates Diverse...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1111/j.1399-3054.2004.00418.x (Jasmonate-regulated Arabidopsis stress signalling network) | DOI:10.​1105/​tpc.​106.​048017 (MYC2 Differentially Modulates Diverse...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1111/j.1399-3054.2004.00418.x (Jasmonate-regulated Arabidopsis stress signalling network) | DOI:10.​1105/​tpc.​106.​048017 (MYC2 Differentially Modulates Diverse...)
# | | 160 b'\xc2\xa0'
# DOI:10.1094/MPMI-23-9-1151 (Manosalva, 2010; : Methyl esterase 1 (StMES1) is required...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# AraCyc:PWY-981 | DOI:​10.​1104/​pp.​103.​2.​315 (Pathway of Salicylic Acid Biosynthesis...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.​1105/​tpc.​104.​027441 (Interaction of NIMIN1 with NPR1...) | DOI:10.1016/S1369-5266(03)00058-X (The salicylic acid loop in plant defense)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.​1105/​tpc.​104.​027441 (Interaction of NIMIN1 with NPR1...) | DOI:10.1016/S1369-5266(03)00058-X (The salicylic acid loop in plant defense)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.​1105/​tpc.​104.​027441 (Interaction of NIMIN1 with NPR1...) | DOI:10.1016/S1369-5266(03)00058-X (The salicylic acid loop in plant defense)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.​1105/​tpc.​104.​027441 (Interaction of NIMIN1 with NPR1...) | DOI:10.1016/S1369-5266(03)00058-X (The salicylic acid loop in plant defense)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1038/415977a (MAP kinase signalling cascade in...) | DOI:​10.​1105/​tpc.​015552 (Silencing of the Mitogen-Activated...) | DOI:10.1007/s00425-010-1308-5 (A broad-spectrum, efficient and nontransgenic...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1038/415977a (MAP kinase signalling cascade in...) | DOI:​10.​1105/​tpc.​015552 (Silencing of the Mitogen-Activated...) | DOI:10.1007/s00425-010-1308-5 (A broad-spectrum, efficient and nontransgenic...)
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.113.117838 (Jiang, 2014: Arabidopsis WRKY57 functions as a node of convergence...)
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.113.117838 (Jiang, 2014: Arabidopsis WRKY57 functions as a node of convergence...)
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.113.117838 (Jiang, 2014: Arabidopsis WRKY57 functions as a node of convergence...)
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.113.117838 (Jiang, 2014: Arabidopsis WRKY57 functions as a node of convergence...)
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.113.117838 (Jiang, 2014: Arabidopsis WRKY57 functions as a node of convergence...)
# |–| 8211 b'\xe2\x80\x93'
# DOI:10.1105/tpc.112.109074 (Meng, 2013: Phosphorylation of an ERF ...) Meng X, Xu J, He Y, Yang K-Y, Mordorski B., et al. 2013. Phosphorylation of an ERF transcription factor by Arabidopsis MPK3/MPK6 regulates plant defense gene induction and fungal resistance. Plant Cell 25(3):1126–42
# |–| 8211 b'\xe2\x80\x93'
# DOI:10.1105/tpc.112.109074 (Meng, 2013: Phosphorylation of an ERF ...) Meng X, Xu J, He Y, Yang K-Y, Mordorski B., et al. 2013. Phosphorylation of an ERF transcription factor by Arabidopsis MPK3/MPK6 regulates plant defense gene induction and fungal resistance. Plant Cell 25(3):1126–42
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# DOI:10.1093/mp/ssr113 (Zander, 2012: Repression of the Arabidopsis thaliana JA/ET-induced defense...) | PMID:24989234 (Zander, 2014: TGA Transcription Factors Activate the SA-Suppressible Branch ...)
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# DOI:10.1093/mp/ssr113 (Zander, 2012: Repression of the Arabidopsis thaliana JA/ET-induced defense...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# DOI:10.​1105/​tpc.​108.​058974 (Fode, 2008: The Arabidopsis GRAS Protein SCL14 Interacts...)
# |​| 8203 b'\xe2\x80\x8b'
# | | 160 b'\xc2\xa0'
# DOI:​10.1105/tpc.113.121731 (Qi, 2014: Arabidopsis DELLA and JAZ Proteins...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# DOI:10.​1105/​tpc.​112.​101428 (Wild, 2012: The Arabidopsis DELLA RGA-LIKE3...)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.3390/plants3010160 Functions of Calcium-Dependent Protein Kinases…
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.3390/plants3010160 Functions of Calcium-Dependent Protein Kinases… ker R-gene unknown also this interaction postulated
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1038/nature07612 (Du, 2009: Ca2+_calmodulin regulates ...) | DOI:10.​1104/​pp.​111.​192310 (Nie, 2012: SR1, a Calmodulin-Binding Transcription Factor ...)
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# |​| 8203 b'\xe2\x80\x8b'
# DOI:10.1038/nature07612 (Du, 2009: Ca2+_calmodulin regulates ...) | DOI:10.​1104/​pp.​111.​192310 (Nie, 2012: SR1, a Calmodulin-Binding Transcription Factor ...)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.3390/plants3010160 Functions of Calcium-Dependent Protein Kinases…
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.3390/plants3010160 Functions of Calcium-Dependent Protein Kinases…
# | | 160 b'\xc2\xa0'
# DOI:10.1105/tpc.108.065193.
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
# |…| 8230 b'\xe2\x80\xa6'
# DOI:10.1016/j.chom.2012.04.014. (coronatine promotes….)
#
# AdditionalInfo
# -------------
# |–| 8211 b'\xe2\x80\x93'
# |β| 946 b'\xce\xb2'
# Acyl-CoA oxidase: In Arabidopsis, five genes appear to en-code acyl-CoA oxidases (ACX1–ACX5, with varying chain-length specificities). Mutant analysis indicated that ACX1 and ACX5 act redundantly in initiating β-oxidation of OPC-8:0-CoA. Beta-oxidation itself involves three core enzymes, acyl-CoA oxi-dase (ACX), multifunctional protein (MFP; comprising enoyl-CoA hydratase and b-hydroxy-acyl-CoA dehydrogenase activities), and 3-ketoacyl-CoA thiolase (KAT).
# | | 160 b'\xc2\xa0'
# bHLH transcription factors EGL3, GL3, and TT8 ; MYB factors MYB75 and GL1;WD-repeat protein TTG1
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# Upregulating the expression of late anthocyanin biosynthetic genes: including NADPH-dependent dihydroflavonol reductase(DFR), leucoanthocyanidin dioxygenase (LDOX), and UDP-Glc:flavonoid 3-Oglucosyltransferase (UF3GT).
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# Upregulating the expression of late anthocyanin biosynthetic genes: including NADPH-dependent dihydroflavonol reductase(DFR), leucoanthocyanidin dioxygenase (LDOX), and UDP-Glc:flavonoid 3-Oglucosyltransferase (UF3GT).
# |…| 8230 b'\xe2\x80\xa6'
# Targets to proteasome (er ligase); HECT domain E3 ubiquitin ligase UPL5 … UPL5 regulates leaf senescence in Arabidopsis through degradation of WRKY53 and ensures that senescence is executed in the correct time frame.
# | | 160 b'\xc2\xa0'
# MEKK1/MAPKKK8 (=MAP3K) AT4G08500
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# based on evidence that the activity of CBP60, WRKY8/28/48, and CAMTA3/SR1 factors are modulated by calcium dependent protein kinases (CDPKs) and calmodulin (CaM; Du et al., 2009; Gao et al., 2013; Truman et al., 2013)
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# | | 160 b'\xc2\xa0'
# based on evidence that the activity of CBP60, WRKY8/28/48, and CAMTA3/SR1 factors are modulated by calcium dependent protein kinases (CDPKs) and calmodulin (CaM; Du et al., 2009; Gao et al., 2013; Truman et al., 2013)
# | | 160 b'\xc2\xa0'
# Control of salicylic acid synthesis and systemic acquired
# |β| 946 b'\xce\xb2'
# Original reaction had ntaCF1-beta (P00826 in SwissProt; Z00044.2 in GenBank), closest match in TAIR10 is ATCG00480 (ATPB). NtCF1-beta is a subunit of chloroplast ATP synthase. HC-Pro may interfere with the assembly of NtCF1β -subunit into the whole enzyme. HC-Pro from PVY with Y1H.
# | | 160 b'\xc2\xa0'
# Control of salicylic acid synthesis and systemic acquired
# |´| 180 b'\xc2\xb4'
# cZ synthesis; enzyme 5´- ribonucleotide phosphohydrolase
# |´| 180 b'\xc2\xb4'
# DHZ synthesis; enzyme 5´- ribonucleotide phosphohydrolase
# |´| 180 b'\xc2\xb4'
# tZ synthesis; enzyme 5´- ribonucleotide phosphohydrolase
# |´| 180 b'\xc2\xb4'
# iP synthesis; enzyme 5´- ribonucleotide phosphohydrolase
# |´| 180 b'\xc2\xb4'
# CCD7 cleaves 9-cis-b-carotene into 9-cis-b-apo-10´-carotenal (Output_1) and b-ionone (Output_2)
#
# Comment
# -------------
# |š| 353 b'\xc5\xa1'
# |Ž| 381 b'\xc5\xbd'
# |č| 269 b'\xc4\x8d'
# deaktivacija aktivnih GA-vprašaj Živo če ok
# |š| 353 b'\xc5\xa1'
# |Ž| 381 b'\xc5\xbd'
# |č| 269 b'\xc4\x8d'
# deaktivacija aktivnih GA-vprašaj Živo če ok
#
# ModelV
# -------------
#
# kinetics
# -------------
#
# origin
# -------------
#
# trust_level
# -------------
#
# also_observed_in
# -------------

# %%
for c in bad_cols:
    df_edges[c] = df_edges[c].apply(replacer)

# %%
def doi_list(x):
    x = x.lower()
    match = re.findall("(?:doi)(?:\:|\/)\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["doi:" + m.rstrip('.') for m in match]
    else:
        return []

def pubmed_list(x):
    x =x.lower()
    match = re.findall("(?:pmid)\:\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["pmid:" + m.rstrip('.') for m in match]
    else:
        return []

# %%
# format literature sources
df_edges["Literature"].fillna(value="", inplace=True)
for i, row in df_edges.iterrows():
    s = row['Literature']
    source = doi_list(s)
    source += pubmed_list(s)
    for z in s.split("|"):
        key = z.lower()
        if ":" in key:
            if "aracyc" in key:
                aracyc_string = "aracyc:" + z.split(":")[1].strip()
                source.append(aracyc_string)
            elif "kegg" in key:
                kegg_string = "kegg:" + z.split(":")[1].strip()
                source.append(kegg_string)
            elif "doi" in key:
                # already fetched
                continue
            elif ("pubmed" in key) or ("pmid" in key):
                pmid_string = "pubmed:" + z.split(":")[1].strip()
        elif "invented" in key:
            source.append("invented")
        else:
            print("no/bad reference", row['ConnID'], row['origin'], z)
            source.append("other:" + z.strip())
    if len(source) > 0:
        df_edges.loc[i, "literature_sources"] = helpers.list_to_string(source)
    else:
        print(row['ConnID'], row['origin'], z)
# Out:
# no/bad reference Conn040 v2.7.5_PIS-model-Reactions
# no/bad reference Conn118 v2.7.5_PIS-model-Reactions
# no/bad reference Conn120 v2.7.5_PIS-model-Reactions
# no/bad reference Conn122 v2.7.5_PIS-model-Reactions
# no/bad reference Conn182 v2.7.5_PIS-model-Reactions
# no/bad reference Conn183 v2.7.5_PIS-model-Reactions
# no/bad reference Conn199 v2.7.5_PIS-model-Reactions ? Kg need to find reference
# no/bad reference Conn273 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn274 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn275 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn276 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn276 v2.7.5_PIS-model-Reactions_New  10.1073/pnas.98.4.2065
# no/bad reference Conn277 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn278 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn279 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn280 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn281 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn282 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn283 v2.7.5_PIS-model-Reactions_New KEGG
# no/bad reference Conn309 v2.7.5_PIS-model-Reactions_New

# %%
df_edges[["origin", "ConnID", "Literature", "literature_sources"]].to_csv("lit-check.tsv", sep="\t", index=None)

# %%
df_edges.reset_index(inplace=True, drop=True)

# %%
save_df = df_edges.copy()
#df_edges = save_df.copy()

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.           v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.           v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.           v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...           v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...           v1.0      NaN
#
#                        origin trust_level also_observed_in  \
# 0  v2.7.5_PIS-model-Reactions          R1
# 1  v2.7.5_PIS-model-Reactions          R1
# 2  v2.7.5_PIS-model-Reactions          R1
# 3  v2.7.5_PIS-model-Reactions          R1
# 4  v2.7.5_PIS-model-Reactions          R1
#
#        literature_sources
# 0        aracyc:ETHYL-PWY
# 1        aracyc:ETHYL-PWY
# 2        aracyc:ETHYL-PWY
# 3  doi:10.1105/tpc.001768
# 4  doi:10.1105/tpc.001768
#
# [5 rows x 32 columns]

# %%
for x in ['input1', 'input2', 'input3', 'output1']:
    df_edges.loc[:, x + "_ID"] = df_edges[x + "_ID"].apply(helpers.reorder_ids)

# %% [markdown]
# ## Protein, Clade, Family keys

# %%
node_dict = {}
for label in node_labels:
    q = '''MATCH (n:%s) RETURN DISTINCT n.name'''%label
    s = set([d['n.name'] for d in graph.run(q).data()])
    print(label, len(s))
    node_dict[label] = s
# Out:
# PlantCoding 161
# PlantNonCoding 9
# PlantAbstract 7
# Complex 1
# ExternalOrganism 3
# ExternalCoding 14
# ExternalNonCoding 0
# Process 6
# MetaboliteFamily 11
# Metabolite 102
# Gene 0
# Expression 0

# %%
all_species = ['ath', 'stu', 'osa']

# %%
file_name = os.path.join(input_path, "bio_elements.tsv")
df_bioelements = pd.read_csv(file_name, sep="\t")

# %%
df_bioelements.head()
# Out:
#   AddedBy Species      NodeType Family     Clade     NodeID NodeName  \
# 0      KG     ath  plant_coding    SAM      SAMS  AT1G02500     SAM1
# 1      KG     ath  plant_coding    SAM      SAMS  AT4G01850     SAM2
# 2      KG     ath  plant_coding    SAM      SAMS  AT2G36880     SAM3
# 3      KG     ath  plant_coding    SAM      SAMS  AT3G17390     SAM4
# 4      KG     ath  plant_coding    ACS  ACS1,2,6  AT3G61510     ACS1
#
#   ModelStatus              NodeDescription AdditionalInfo  ...  \
# 0         use  SAM synthetase [EC:2.5.1.6]            NaN  ...
# 1         use  SAM synthetase [EC:2.5.1.6]            NaN  ...
# 2         use  SAM synthetase [EC:2.5.1.6]            NaN  ...
# 3         use  SAM synthetase [EC:2.5.1.6]            NaN  ...
# 4         use   ACC synthase [EC:4.4.1.14]            NaN  ...
#
#          GMM_OCD1                                            GMM_OCD  \
# 0  OCD_all_000621  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 1  OCD_all_000621  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 2  OCD_all_000621  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 3  OCD_all_000621  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 4  OCD_all_000133  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
#
#                                   GMM_Description GMM_ShortName  \
# 0               S-adenosylmethionine synthetase 1          SAM1
# 1               S-adenosylmethionine synthetase 2          SAM2
# 2                methionine adenosyltransferase 3         METK3
# 3  S-adenosylmethionine synthetase family protein         METK4
# 4                                  ACC synthase 1          ACS1
#
#                    GMM_Synonyms    NodeLabel observed_species  \
# 0  AtSAM1,MAT1,METK1,SAM-1,SAM1  PlantCoding              ath
# 1        AtSAM2,MAT2,SAM-2,SAM2  PlantCoding              ath
# 2                    MAT3,METK3  PlantCoding              ath
# 3         MAT4,METK4,MTO3,SAMS3  PlantCoding              ath
# 4             ACC2,ACS1,AT-ACS1  PlantCoding              ath
#
#   also_observed_in chebi_identifier pubmed_identifier
# 0              NaN              NaN               NaN
# 1              NaN              NaN               NaN
# 2              NaN              NaN               NaN
# 3              NaN              NaN               NaN
# 4              NaN              NaN               NaN
#
# [5 rows x 24 columns]

# %%
def pick_the_set(x):
    for v in x:
        if type(v) == set:
            return v
    return {}


def get_species_homologues(level):
    df_level_species  = df_bioelements.groupby([level, 'Species']).agg({
      'NodeID':lambda x: set(x), 
    })
    df_level_species.reset_index(1, inplace=True)

    cols = []
    for specie in all_species:
        col = specie + '_homologues'
        cols.append(col)
        df_level_species.loc[df_level_species['Species'] == specie, col] =\
         df_level_species[df_level_species['Species'] == specie]['NodeID']
    
    df_level_species = df_level_species[cols].groupby(level).agg({
        y:pick_the_set for y in cols
    })
    
    df_level = df_bioelements.groupby(level).agg({
          'AddedBy':lambda x:list(x)[0], 
          'NodeLabel':lambda x:list(x)[0], 
          'NodeDescription':lambda x: ', '.join(list(set(x))), 
          'AdditionalInfo':lambda x: helpers.list_to_string(x), 
          'Process':lambda x:list(x)[0], 
          'ModelV':helpers.get_latest_model, 
          'Species':lambda x: set(x), 
    })    

    df_level = df_level.join(df_level_species[cols])
    df_level.reset_index(inplace=True)
    
    return df_level

# %%
id_to_name = df_bioelements[['NodeID', 'NodeName']]
id_to_name[id_to_name['NodeName'].duplicated()]['NodeName'].unique()
# Out:
# array(['CPS', 'GA20ox3', 'GA20ox1', 'GA20ox4', 'MYB33'], dtype=object)

# %%
df_nodes = get_species_homologues('NodeName')
df_nodes.set_index('NodeName', inplace=True)

df_families = get_species_homologues("Family")

# node name to node IDs
node_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    node_ids_key[col] = df_nodes[col].to_dict()
df_clades = get_species_homologues('Clade')
df_clades.set_index('Clade', inplace=True)

# clade name to node IDs
clade_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    clade_ids_key[col] = df_clades[col].to_dict() 

# family name to node IDs
df_families.set_index("Family", inplace=True)
family_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    family_ids_key[col] = df_families[col].to_dict() 

node_to_family = df_bioelements[["NodeName", "Family"]].set_index("NodeName")["Family"].to_dict()
clade_to_family = df_bioelements[["Clade", "Family"]].set_index("Clade")["Family"].to_dict()

# %%
def convert_node_to_family(x):
    # pathogen proteins are listed as proteins, so cannot use dict
    id_, type_, level_, ConnID, origin = x.values
      
    if id_ in helpers.empty_strings:
        return np.nan, np.nan

    new_label = None
    family_id = None
    
    ########################
    # Simple Cases
    ########################
    if type_ in ['complex', 'complex [active]', 'complex [activated]', 'complex [inactive]', 'plant_complex']:
        if not (id_ in node_dict["Complex"]):
            complexes_to_add.append(id_)
        new_label = 'Complex'
        family_id = id_
    
    elif type_ in ["metabolite"]:
        for label in ["Metabolite", "MetaboliteFamily"]:
            if id_ in node_dict[label]:
                new_label = label
                break
        if not new_label:
            missing_in_components.update([id_])        
            print(origin, "|", ConnID, "|", id_, "|", type_, "|", level_, " |a (label) not a listed metabolite")
        family_id = id_

    elif type_ in ['process']:
        if (id_ in node_dict["Process"]):
            family_id = id_
            new_label = "Process"
        else:
            print(origin, "|", ConnID, "|", id_, "|", type_, "|", level_,  " |b (label) process not a listed process")
        
    else:
        ########################
        # family ID
        ########################
        check_external = False
        if level_ == "family":    
            family_id = id_
        elif level_ in ["clade", "clade/orthologue"]:
            try:
                family_id = clade_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        elif level_ == "node":
            try:
                family_id = node_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        
        if check_external:
            for label in ["ExternalOrganism", "ExternalCoding", "ExternalNonCoding"]:
                if id_ in node_dict[label]:
                    new_label = label
                    family_id = id_
                    break
                    
        if not family_id:
            print(origin, "|", ConnID, "|", id_, "|", type_, "|", level_,  " |c (family id) could not convert to family/external")
                
        ########################
        # Label
        ########################
        if (family_id) and (not new_label):
            id_labels = [] #looping just in case an id occurs mutiple times
            for label in node_labels:
                if family_id in node_dict[label]:
                    id_labels.append(label)

            if len(id_labels) == 1:
                new_label = id_labels[0]
            elif len(id_labels) > 1:
                print(origin, "|", ConnID, "|", id_, "|", type_, "|", level_,  " |d (label) many labels fit")
                missing_in_components.update([id_])       

            else:
                print(origin, "|", ConnID, "|", id_, "|", type_, "|", level_,  " |e (label) could not find label")
                missing_in_components.update([id_])        

    return family_id, new_label

# %%
complexes_to_add = []
missing_in_components = set()
replace_w_family = set()

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, level_col, new_id, new_label_col  =\
            [prefix + x for x in ('_ID',  '_type',  '_level',  '_newID', '_label')]    
    
    df_edges[[new_id, new_label_col]] = df_edges[[id_col, type_col, level_col, 'ConnID', 'origin']].apply(convert_node_to_family, axis=1, result_type='expand')
# Out:
# Model_CK-Reactions_new | nan | DHZRMP | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | DHZRMP | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | metabolite | clade  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | metabolite | clade  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | metabolite | clade  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-B(a)(p) | protein | clade  |c (family id) could not convert to family/external
# v2.7.2_PIS-model-JALR-Reactions_New | Conn273 | All-trans-b-carotene | metabolite | family  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn274 | 9-cis-b-carotene | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn275 | 9-cis-b-apo-10prime-carotenal | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn276 | CL | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn277 | SLs | metabolite | family  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn278 | D14 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn279 | D53 | protein [activated] | family  |e (label) could not find label
# v2.7.5_PIS-model-Reactions_New | Conn308 | miR6022 | plant_ncRNA | node  |c (family id) could not convert to family/external
# v2.7.5_PIS-model-Reactions_New | Conn310 | LSD1 | plant_coding | node  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-B(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-A(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHP1,2,3,4,5(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHP1,2,3,4,5(a)(p) | protein | clade  |c (family id) could not convert to family/external
# v2.7.2_PIS-model-JALR-Reactions_New | Conn276 | MAX1 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn277 | D14 | protein [inactivated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn278 | MAX2 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn279 | D14 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn279 | MAX2 | protein [activated] | nan  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | DHZRMP | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | iPOG | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | iPROG | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | DHZRMP | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | DHZRMP | metabolite | node  |a (label) not a listed metabolite
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHK2,3,4(a) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | AHP1,2,3,4,5(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-A(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ABB-B | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-A(a)(p) | protein | clade  |c (family id) could not convert to family/external
# Model_CK-Reactions_new | nan | ARR-B(a)(p) | protein | clade  |c (family id) could not convert to family/external
# v2.7.2_PIS-model-JALR-Reactions_New | Conn273 | 9-cis-b-carotene | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn274 | 9-cis-b-apo-10prime-carotenal | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn275 | CL | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn276 | CLA | metabolite | node  |a (label) not a listed metabolite
# v2.7.2_PIS-model-JALR-Reactions_New | Conn277 | D14 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn278 | MAX2 | protein [activated] | family  |e (label) could not find label
# v2.7.2_PIS-model-JALR-Reactions_New | Conn279 | D53 | protein [inactivated] | family  |e (label) could not find label

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   also_observed_in      literature_sources input1_newID input1_label  \
# 0                         aracyc:ETHYL-PWY        L-Met   Metabolite
# 1                         aracyc:ETHYL-PWY         SAMe   Metabolite
# 2                         aracyc:ETHYL-PWY          ACC   Metabolite
# 3                   doi:10.1105/tpc.001768         Cu2+   Metabolite
# 4                   doi:10.1105/tpc.001768          ETR  PlantCoding
#
#   input2_newID input2_label input3_newID input3_label output1_newID  \
# 0          SAM  PlantCoding          NaN          NaN          SAMe
# 1          ACS  PlantCoding          NaN          NaN           ACC
# 2          ACO  PlantCoding          NaN          NaN            ET
# 3          HMA  PlantCoding          NaN          NaN          Cu2+
# 4         Cu2+   Metabolite          NaN          NaN           ETR
#
#   output1_label
# 0    Metabolite
# 1    Metabolite
# 2    Metabolite
# 3    Metabolite
# 4   PlantCoding
#
# [5 rows x 40 columns]

# %%
def get_orthologues(x, prefix=""):
    id_, level_, label_ = x.values
    ########################
    # Specie specific homologues
    ########################
    
    return_D = {f"{prefix}_{specie}_homologues":"" for specie in all_species}
    
    if label_ in ['PlantCoding', 'PlantNonCoding',  'PlantAbstract']:

        for species in all_species:
            species = f"{species}_homologues"
            k = f"{prefix}_{species}"
            if level_ == 'node':
                return_D[k] = node_ids_key[species][id_]
            elif level_ == 'clade':
                return_D[k] =  clade_ids_key[species][id_]
            elif level_ == 'family':
                return_D[k] =  family_ids_key[species][id_]

    return_D = {x:helpers.list_to_string(list(return_D[x])) for x in return_D}
    return return_D

# %%
new_dfs = []
for prefix in ['input1', 'input2', 'input3', 'output1']:
    print(prefix)
    id_col, level_col, new_label_col  =\
                [prefix + x for x in ('_ID',  '_level',  '_label')]        
    
    new_df = df_edges[[id_col, level_col, new_label_col ]].apply(get_orthologues, axis=1, result_type='expand', prefix=prefix)
    new_dfs.append(new_df)
    #df_edges = df_edges.join(new_df, sort=False)
# Out:
# input1
# input2
# input3
# output1

# %%
homologues_df = pd.concat(new_dfs, sort=False, axis=1)

# %%
homologues_df.loc[0]
# Out:
# input1_ath_homologues
# input1_osa_homologues
# input1_stu_homologues
# input2_ath_homologues     AT4G01850,AT3G17390,AT1G02500,AT2G36880
# input2_osa_homologues
# input2_stu_homologues
# input3_ath_homologues
# input3_osa_homologues
# input3_stu_homologues
# output1_ath_homologues
# output1_osa_homologues
# output1_stu_homologues
# Name: 0, dtype: object

# %%
df_edges = df_edges.join(homologues_df, sort=False)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input1_stu_homologues                              input2_ath_homologues  \
# 0                                  AT4G01850,AT3G17390,AT1G02500,AT2G36880
# 1                        AT3G61510,AT4G08040,AT2G22810,AT1G62960,AT5G51...
# 2                        AT2G19590,AT1G05010,AT1G77330,AT1G62380,AT1G12010
# 3                                  AT1G63440,AT4G33520,AT5G44790,AT5G21930
# 4
#
#   input2_osa_homologues input2_stu_homologues input3_ath_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#   input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT1G66340,AT3G04580,AT1G04310,AT2G40940,AT3G23150
#
#   output1_stu_homologues
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 52 columns]

# %%
node_type_to_node_form_dict = {
    "gene":"gene",
    
    "protein":"protein",
    "protein [inactivated]":"protein", 
    "protein [activated]":"protein_active",
    'protein [active]': "protein_active",
    
    "ncRNA":"ncRNA",
    "plant_ncRNA":"ncRNA",
    'ta-siRNA':"ta-siRNA", 
        
    "complex":"complex", 
    "plant_complex":"complex",
    'complex [active]': "complex_active",
    
    "metabolite":"metabolite",
    
    "process":"process", 
    'process [active]':"process_active",

    np.nan:"", 
    "plant_coding":"unknown"
}

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, new_form_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_form')]
    
    x = df_edges[[id_col, type_col]].dropna(how='all')
    
    print(prefix)
    df_edges[new_form_col] = df_edges[type_col].apply(lambda x: node_type_to_node_form_dict[x])
# Out:
# input1
# input2
# input3
# output1

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input3_ath_homologues input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT1G66340,AT3G04580,AT1G04310,AT2G40940,AT3G23150
#
#   output1_stu_homologues input1_form     input2_form input3_form  \
# 0                         metabolite  protein_active
# 1                         metabolite  protein_active
# 2                         metabolite  protein_active
# 3                         metabolite         protein
# 4                            protein      metabolite
#
#      output1_form
# 0      metabolite
# 1      metabolite
# 2      metabolite
# 3      metabolite
# 4  protein_active
#
# [5 rows x 56 columns]

# %%
node_localisation_dict = {
    'nuc':'nucleus',
    'er':'endoplasmic reticulum',
    'golgi':'golgi apparatus', 
    'mitochondria?': 'putative:mitochondrion'
}


good_localisations = set([
     'nucleus',
     'nucleolus',
     'cytoplasm',
     'vacuole',
     'endoplasmic reticulum',
     'chloroplast',
     'mitochondrion',
     'golgi apparatus',
     'peroxisome',
     'apoplast',
     'extracellular'
])

good_localisations.update(['putative:' + s for s in good_localisations])


def node_localisation_std(x):
    if not type(x) == str:
        return ""
    
    x = x.lower()
    if x in node_localisation_dict.keys():
        x = node_localisation_dict[x]
    
    if x in good_localisations:
        return x
    else:
        return ""

node_localisations = set()
new_localisation = set()
for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, localisation_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_localisation')]
    
    x = df_edges[['ConnID', 'origin', id_col, localisation_col]].dropna(how='all', subset=[ id_col, localisation_col])
    
    for _, y in x.iterrows():
        if (not (y[id_col] in helpers.empty_strings)) and (y[localisation_col] in helpers.empty_strings):
            print(y['origin'], y['ConnID'], prefix, y[id_col], y[localisation_col])
    
    
    node_localisations.update(x[localisation_col])
    
    #print(prefix)
    df_edges[localisation_col] = df_edges[localisation_col].apply(node_localisation_std)
    
    new_localisation.update(df_edges[localisation_col])
# Out:
# v2.7.5_PIS-model-Reactions Conn024 input1 PR3 nan
# v2.7.5_PIS-model-Reactions Conn025 input1 PR4 nan
# v2.7.5_PIS-model-Reactions Conn066 input1 CLH nan
# v2.7.5_PIS-model-Reactions Conn067 input1 JR1 nan
# v2.7.5_PIS-model-Reactions Conn068 input1 PR13 nan
# v2.7.5_PIS-model-Reactions Conn069 input1 VSP nan
# v2.7.5_PIS-model-Reactions Conn080 input1 Anthocyanin-accumulation nan
# v2.7.5_PIS-model-Reactions Conn080 input1 Trichome-initiation nan
# v2.7.5_PIS-model-Reactions Conn104 input1 PR1 nan
# v2.7.5_PIS-model-Reactions Conn105 input1 PR2 nan
# v2.7.5_PIS-model-Reactions Conn106 input1 PR5 nan
# v2.7.5_PIS-model-Reactions Conn126 input1 WRKY53 nan
# v2.7.5_PIS-model-Reactions Conn172 input1 R-gene nan
# v2.7.5_PIS-model-Reactions_New Conn273 input1 Geranylgeranyl-PP  nan
# v2.7.5_PIS-model-Reactions_New Conn274 input1 ent-Copalyl-PP nan
# v2.7.5_PIS-model-Reactions_New Conn275 input1 ent-Kaurene nan
# v2.7.5_PIS-model-Reactions_New Conn276 input1 ent-Kaurenoic acid nan
# v2.7.5_PIS-model-Reactions_New Conn277 input1 GA12 nan
# v2.7.5_PIS-model-Reactions_New Conn278 input1 GA12 nan
# v2.7.5_PIS-model-Reactions_New Conn279 input1 GA9 nan
# v2.7.5_PIS-model-Reactions_New Conn280 input1 GA20 nan
# v2.7.5_PIS-model-Reactions_New Conn281 input1 GA20 nan
# v2.7.5_PIS-model-Reactions_New Conn282 input1 GA1 nan
# v2.7.5_PIS-model-Reactions_New Conn283 input1 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn284 input1 vsiRNA34327 nan
# v2.7.5_PIS-model-Reactions_New Conn285 input1 vsiRNA12986 nan
# v2.7.5_PIS-model-Reactions_New Conn286 input1 miR167e-3p nan
# v2.7.5_PIS-model-Reactions_New Conn287 input1 miR167e-3p nan
# v2.7.5_PIS-model-Reactions_New Conn288 input1 miR167e-3p nan
# v2.7.5_PIS-model-Reactions_New Conn289 input1 miR167e-3p nan
# v2.7.5_PIS-model-Reactions_New Conn290 input1 miR167e-3p nan
# v2.7.5_PIS-model-Reactions_New Conn291 input1 phasiRNA931 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GID1a,b,c nan
# v2.7.5_PIS-model-Reactions_New nan input1 GID1a,b,c nan
# v2.7.5_PIS-model-Reactions_New nan input1 GID1a,b,c nan
# v2.7.5_PIS-model-Reactions_New Conn292 input1 GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn293 input1 GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn294 input1 GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn295 input1 GA1-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn296 input1 GA3-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn297 input1 GA4-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GA1-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GA3-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GA4-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan input1 SLY1 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GID2 nan
# v2.7.5_PIS-model-Reactions_New nan input1 GA1-GID1-DELLA nan
# v2.7.5_PIS-model-Reactions_New nan input1 GA1-GID1-SLR1 nan
# v2.7.5_PIS-model-Reactions_New Conn299 input1 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn300 input1 GA3 nan
# v2.7.5_PIS-model-Reactions_New Conn301 input1 GA1 nan
# v2.7.5_PIS-model-Reactions_New Conn302 input1 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn303 input1 GA3 nan
# v2.7.5_PIS-model-Reactions_New Conn304 input1 GA1 nan
# v2.7.5_PIS-model-Reactions_New Conn305 input1 miR159a nan
# v2.7.5_PIS-model-Reactions_New Conn306 input1 miR159b nan
# v2.7.5_PIS-model-Reactions_New Conn307 input1 miR319a-3p nan
# v2.7.5_PIS-model-Reactions_New Conn308 input1 MYB33 nan
# v2.7.5_PIS-model-Reactions_New Conn309 input1 WRKY6 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input1 CAT nan
# v2.7.5_PIS-model-Reactions_New Conn310 input1 SA nan
# v2.7.5_PIS-model-Reactions_New Conn310 input1 CAT2 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input1 CAT2 nan
# Model_CK-Reactions_new nan input1 HMBDP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 DMAPP nan
# Model_CK-Reactions_new nan input1 prenyl-tRNA nan
# Model_CK-Reactions_new nan input1 cis-prenyl-tRNA nan
# Model_CK-Reactions_new nan input1 cZRMP nan
# Model_CK-Reactions_new nan input1 cZRMP nan
# Model_CK-Reactions_new nan input1 cZR nan
# Model_CK-Reactions_new nan input1 cZR nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 cZOG nan
# Model_CK-Reactions_new nan input1 cZROG nan
# Model_CK-Reactions_new nan input1 DHZRMP nan
# Model_CK-Reactions_new nan input1 DHZRMP nan
# Model_CK-Reactions_new nan input1 DHZR nan
# Model_CK-Reactions_new nan input1 DHZR nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 DHZOG nan
# Model_CK-Reactions_new nan input1 DHZROG nan
# Model_CK-Reactions_new nan input1 tZRMP nan
# Model_CK-Reactions_new nan input1 tZRMP nan
# Model_CK-Reactions_new nan input1 tZR nan
# Model_CK-Reactions_new nan input1 tZR nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 tZOG nan
# Model_CK-Reactions_new nan input1 tZROG nan
# Model_CK-Reactions_new nan input1 iPRMP nan
# Model_CK-Reactions_new nan input1 iPRMP nan
# Model_CK-Reactions_new nan input1 iPR nan
# Model_CK-Reactions_new nan input1 iPR nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 iPRTP nan
# Model_CK-Reactions_new nan input1 iPRDP nan
# Model_CK-Reactions_new nan input1 iPRMP nan
# Model_CK-Reactions_new nan input1 tZRMP nan
# Model_CK-Reactions_new nan input1 iPRTP nan
# Model_CK-Reactions_new nan input1 iPRDP nan
# Model_CK-Reactions_new nan input1 tZRTP nan
# Model_CK-Reactions_new nan input1 tZRDP nan
# Model_CK-Reactions_new nan input1 iP nan
# Model_CK-Reactions_new nan input1 tZ nan
# Model_CK-Reactions_new nan input1 cZ nan
# Model_CK-Reactions_new nan input1 DHZ nan
# Model_CK-Reactions_new nan input1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input1 AHP6 nan
# Model_CK-Reactions_new nan input1 AHP1,2,3,4,5 nan
# Model_CK-Reactions_new nan input1 ARR-A nan
# Model_CK-Reactions_new nan input1 ARR-B(a)(p) nan
# Model_CK-Reactions_new nan input1 ARR-A nan
# Model_CK-Reactions_new nan input1 ARR-B nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn273 input1 All-trans-b-carotene nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn274 input1 9-cis-b-carotene nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn275 input1 9-cis-b-apo-10prime-carotenal nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn276 input1 CL nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn277 input1 SLs nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn278 input1 D14 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn279 input1 D53 nan
# v2.7.5_PIS-model-Reactions Conn024 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn025 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn056 input2 SAG101 nan
# v2.7.5_PIS-model-Reactions Conn066 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn067 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn068 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn069 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn080 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn080 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn104 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn105 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn106 input2 potyvirus nan
# v2.7.5_PIS-model-Reactions Conn126 input2 UPL5 nan
# v2.7.5_PIS-model-Reactions Conn172 input2 Ca2+ nan
# v2.7.5_PIS-model-Reactions_New Conn273 input2 CPS nan
# v2.7.5_PIS-model-Reactions_New Conn274 input2 KS nan
# v2.7.5_PIS-model-Reactions_New Conn275 input2 KO nan
# v2.7.5_PIS-model-Reactions_New Conn276 input2 KAO1,2 nan
# v2.7.5_PIS-model-Reactions_New Conn277 input2 GA20ox nan
# v2.7.5_PIS-model-Reactions_New Conn278 input2 GA20ox nan
# v2.7.5_PIS-model-Reactions_New Conn279 input2 GA3ox nan
# v2.7.5_PIS-model-Reactions_New Conn280 input2 GA3ox nan
# v2.7.5_PIS-model-Reactions_New Conn281 input2 GA3ox nan
# v2.7.5_PIS-model-Reactions_New Conn282 input2 C19-GA2ox nan
# v2.7.5_PIS-model-Reactions_New Conn283 input2 C19-GA2ox nan
# v2.7.5_PIS-model-Reactions_New Conn284 input2 CPS nan
# v2.7.5_PIS-model-Reactions_New Conn285 input2 GA20ox3 nan
# v2.7.5_PIS-model-Reactions_New Conn286 input2 GA20ox3 nan
# v2.7.5_PIS-model-Reactions_New Conn287 input2 GA20ox1 nan
# v2.7.5_PIS-model-Reactions_New Conn288 input2 GA20ox4 nan
# v2.7.5_PIS-model-Reactions_New Conn289 input2 Sotub09g017710.1.1 nan
# v2.7.5_PIS-model-Reactions_New Conn290 input2 Sotub10g011620.1.1 nan
# v2.7.5_PIS-model-Reactions_New Conn291 input2 GA3ox nan
# v2.7.5_PIS-model-Reactions_New nan input2 GA1 nan
# v2.7.5_PIS-model-Reactions_New nan input2 GA3 nan
# v2.7.5_PIS-model-Reactions_New nan input2 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn292 input2 GA1 nan
# v2.7.5_PIS-model-Reactions_New Conn293 input2 GA3 nan
# v2.7.5_PIS-model-Reactions_New Conn294 input2 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn295 input2 SLR1 nan
# v2.7.5_PIS-model-Reactions_New Conn296 input2 SLR1 nan
# v2.7.5_PIS-model-Reactions_New Conn297 input2 SLR1 nan
# v2.7.5_PIS-model-Reactions_New nan input2 DELLA nan
# v2.7.5_PIS-model-Reactions_New nan input2 DELLA nan
# v2.7.5_PIS-model-Reactions_New nan input2 DELLA nan
# v2.7.5_PIS-model-Reactions_New nan input2 SCF nan
# v2.7.5_PIS-model-Reactions_New nan input2 SCF nan
# v2.7.5_PIS-model-Reactions_New nan input2 SCF-SLY1 nan
# v2.7.5_PIS-model-Reactions_New nan input2 SCF-GID2 nan
# v2.7.5_PIS-model-Reactions_New Conn299 input2 GAMT1,2 nan
# v2.7.5_PIS-model-Reactions_New Conn300 input2 GAMT1,2 nan
# v2.7.5_PIS-model-Reactions_New Conn301 input2 GAMT1,2 nan
# v2.7.5_PIS-model-Reactions_New Conn302 input2 GAMYB nan
# v2.7.5_PIS-model-Reactions_New Conn303 input2 GAMYB nan
# v2.7.5_PIS-model-Reactions_New Conn304 input2 GAMYB nan
# v2.7.5_PIS-model-Reactions_New Conn305 input2 MYB33 nan
# v2.7.5_PIS-model-Reactions_New Conn306 input2 MYB65 nan
# v2.7.5_PIS-model-Reactions_New Conn307 input2 MYB33 nan
# v2.7.5_PIS-model-Reactions_New Conn308 input2 miR6022 nan
# v2.7.5_PIS-model-Reactions_New Conn309 input2 NPR1 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input2 LSD1 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input2 CAT2 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input2 ACX2 nan
# v2.7.5_PIS-model-Reactions_New Conn310 input2 ACX3 nan
# Model_CK-Reactions_new nan input2 ISPH nan
# Model_CK-Reactions_new nan input2 IPT4,6 nan
# Model_CK-Reactions_new nan input2 IPT2,9 nan
# Model_CK-Reactions_new nan input2 IPT1,3,5,7,8 nan
# Model_CK-Reactions_new nan input2 IPT4,6 nan
# Model_CK-Reactions_new nan input2 IPT1,3,5,7,8 nan
# Model_CK-Reactions_new nan input2 IPT1,3,5,7,8 nan
# Model_CK-Reactions_new nan input2 APT nan
# Model_CK-Reactions_new nan input2 LOG nan
# Model_CK-Reactions_new nan input2 ADK nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 APT nan
# Model_CK-Reactions_new nan input2 LOG nan
# Model_CK-Reactions_new nan input2 ADK nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 APT nan
# Model_CK-Reactions_new nan input2 LOG nan
# Model_CK-Reactions_new nan input2 ADK nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 UGT73C1,C5 nan
# Model_CK-Reactions_new nan input2 APT nan
# Model_CK-Reactions_new nan input2 LOG nan
# Model_CK-Reactions_new nan input2 ADK nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 CKX nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT76C1,C2 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 UGT85A1 nan
# Model_CK-Reactions_new nan input2 CYP735A1,A2 nan
# Model_CK-Reactions_new nan input2 CYP735A1,A2 nan
# Model_CK-Reactions_new nan input2 CYP735A1,A2 nan
# Model_CK-Reactions_new nan input2 tZ nan
# Model_CK-Reactions_new nan input2 cZ nan
# Model_CK-Reactions_new nan input2 DZ nan
# Model_CK-Reactions_new nan input2 iP nan
# Model_CK-Reactions_new nan input2 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input2 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan input2 ARR-B(a)(p) nan
# Model_CK-Reactions_new nan input2 ARR-A(a)(p) nan
# Model_CK-Reactions_new nan input2 AHP1,2,3,4,5(a)(p) nan
# Model_CK-Reactions_new nan input2 AHP1,2,3,4,5(a)(p) nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn273 input2 D27 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn274 input2 CCD7 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn275 input2 CCD8 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn276 input2 MAX1 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn277 input2 D14 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn278 input2 MAX2 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn279 input2 D14 nan
# v2.7.5_PIS-model-Reactions Conn042 input3 JAR nan
# Model_CK-Reactions_new nan input3 ATP nan
# Model_CK-Reactions_new nan input3 tRNA nan
# Model_CK-Reactions_new nan input3 ATP nan
# Model_CK-Reactions_new nan input3 ADP nan
# Model_CK-Reactions_new nan input3 ADP nan
# Model_CK-Reactions_new nan input3 AMP nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# Model_CK-Reactions_new nan input3 Glu nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn279 input3 MAX2 nan
# v2.7.5_PIS-model-Reactions_New Conn273 output1 ent-Copalyl-PP nan
# v2.7.5_PIS-model-Reactions_New Conn274 output1 ent-Kaurene nan
# v2.7.5_PIS-model-Reactions_New Conn275 output1 ent-Kaurenoic acid nan
# v2.7.5_PIS-model-Reactions_New Conn276 output1 GA12 nan
# v2.7.5_PIS-model-Reactions_New Conn277 output1 GA9 nan
# v2.7.5_PIS-model-Reactions_New Conn278 output1 GA20 nan
# v2.7.5_PIS-model-Reactions_New Conn279 output1 GA4 nan
# v2.7.5_PIS-model-Reactions_New Conn280 output1 GA3 nan
# v2.7.5_PIS-model-Reactions_New Conn281 output1 GA1 nan
# v2.7.5_PIS-model-Reactions_New Conn282 output1 GA8 nan
# v2.7.5_PIS-model-Reactions_New Conn283 output1 GA34 nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA1-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA3-GID1 nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA4-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn292 output1 GA1-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn293 output1 GA3-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn294 output1 GA4-GID1 nan
# v2.7.5_PIS-model-Reactions_New Conn295 output1 GA1-GID1-SLR1 nan
# v2.7.5_PIS-model-Reactions_New Conn296 output1 GA3-GID1-SLR1 nan
# v2.7.5_PIS-model-Reactions_New Conn297 output1 GA4-GID1-SLR1 nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA1-GID1-DELLA nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA3-GID1-DELLA nan
# v2.7.5_PIS-model-Reactions_New nan output1 GA4-GID1-DELLA nan
# v2.7.5_PIS-model-Reactions_New nan output1 SCF-SLY1 nan
# v2.7.5_PIS-model-Reactions_New nan output1 SCF-GID2 nan
# v2.7.5_PIS-model-Reactions_New Conn299 output1 GA4-methylester nan
# v2.7.5_PIS-model-Reactions_New Conn300 output1 GA3-methylester nan
# v2.7.5_PIS-model-Reactions_New Conn301 output1 GA1-methylester nan
# Model_CK-Reactions_new nan output1 DMAPP nan
# Model_CK-Reactions_new nan output1 iPRTP nan
# Model_CK-Reactions_new nan output1 prenyl-tRNA nan
# Model_CK-Reactions_new nan output1 iPRTP nan
# Model_CK-Reactions_new nan output1 iPRDP nan
# Model_CK-Reactions_new nan output1 iPRDP nan
# Model_CK-Reactions_new nan output1 iPRMP nan
# Model_CK-Reactions_new nan output1 cis-prenyl-tRNA nan
# Model_CK-Reactions_new nan output1 cZRMP nan
# Model_CK-Reactions_new nan output1 cZR nan
# Model_CK-Reactions_new nan output1 cZ nan
# Model_CK-Reactions_new nan output1 cZ nan
# Model_CK-Reactions_new nan output1 cZRMP nan
# Model_CK-Reactions_new nan output1 cZR nan
# Model_CK-Reactions_new nan output1 Ade nan
# Model_CK-Reactions_new nan output1 Ado nan
# Model_CK-Reactions_new nan output1 cZ7G nan
# Model_CK-Reactions_new nan output1 cZ9G nan
# Model_CK-Reactions_new nan output1 cZOG nan
# Model_CK-Reactions_new nan output1 cZROG nan
# Model_CK-Reactions_new nan output1 cZROG nan
# Model_CK-Reactions_new nan output1 cZOG nan
# Model_CK-Reactions_new nan output1 cZ nan
# Model_CK-Reactions_new nan output1 cZ nan
# Model_CK-Reactions_new nan output1 DHZR nan
# Model_CK-Reactions_new nan output1 DHZ nan
# Model_CK-Reactions_new nan output1 DHZ nan
# Model_CK-Reactions_new nan output1 DHZRMP nan
# Model_CK-Reactions_new nan output1 DHZR nan
# Model_CK-Reactions_new nan output1 Ade nan
# Model_CK-Reactions_new nan output1 Ado nan
# Model_CK-Reactions_new nan output1 DHZ7G nan
# Model_CK-Reactions_new nan output1 DHZ9G nan
# Model_CK-Reactions_new nan output1 DHZOG nan
# Model_CK-Reactions_new nan output1 DHZROG nan
# Model_CK-Reactions_new nan output1 DHZROG nan
# Model_CK-Reactions_new nan output1 DHZOG nan
# Model_CK-Reactions_new nan output1 DHZ nan
# Model_CK-Reactions_new nan output1 DHZ nan
# Model_CK-Reactions_new nan output1 tZR nan
# Model_CK-Reactions_new nan output1 tZ nan
# Model_CK-Reactions_new nan output1 tZ nan
# Model_CK-Reactions_new nan output1 tZRMP nan
# Model_CK-Reactions_new nan output1 tZR nan
# Model_CK-Reactions_new nan output1 Ade nan
# Model_CK-Reactions_new nan output1 Ado nan
# Model_CK-Reactions_new nan output1 tZ7G nan
# Model_CK-Reactions_new nan output1 tZ9G nan
# Model_CK-Reactions_new nan output1 tZOG nan
# Model_CK-Reactions_new nan output1 tZROG nan
# Model_CK-Reactions_new nan output1 tZROG nan
# Model_CK-Reactions_new nan output1 tZOG nan
# Model_CK-Reactions_new nan output1 tZ nan
# Model_CK-Reactions_new nan output1 tZ nan
# Model_CK-Reactions_new nan output1 iPR nan
# Model_CK-Reactions_new nan output1 iP nan
# Model_CK-Reactions_new nan output1 iP nan
# Model_CK-Reactions_new nan output1 iPRMP nan
# Model_CK-Reactions_new nan output1 iPR nan
# Model_CK-Reactions_new nan output1 Ade nan
# Model_CK-Reactions_new nan output1 Ado nan
# Model_CK-Reactions_new nan output1 iP7G nan
# Model_CK-Reactions_new nan output1 iP9G nan
# Model_CK-Reactions_new nan output1 iPOG nan
# Model_CK-Reactions_new nan output1 iPROG nan
# Model_CK-Reactions_new nan output1 tZRTP nan
# Model_CK-Reactions_new nan output1 tZRDP nan
# Model_CK-Reactions_new nan output1 tZRMP nan
# Model_CK-Reactions_new nan output1 DHZRMP nan
# Model_CK-Reactions_new nan output1 iPRDP nan
# Model_CK-Reactions_new nan output1 iPRMP nan
# Model_CK-Reactions_new nan output1 tZRDP nan
# Model_CK-Reactions_new nan output1 tZRMP nan
# Model_CK-Reactions_new nan output1 iPRMP nan
# Model_CK-Reactions_new nan output1 tZRMP nan
# Model_CK-Reactions_new nan output1 cZRMP nan
# Model_CK-Reactions_new nan output1 DHZRMP nan
# Model_CK-Reactions_new nan output1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan output1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan output1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan output1 AHK2,3,4(a) nan
# Model_CK-Reactions_new nan output1 AHP1,2,3,4,5(a)(p) nan
# Model_CK-Reactions_new nan output1 ARR-A(a)(p) nan
# Model_CK-Reactions_new nan output1 ABB-B nan
# Model_CK-Reactions_new nan output1 ARR-A(a)(p) nan
# Model_CK-Reactions_new nan output1 ARR-B(a)(p) nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn273 output1 9-cis-b-carotene nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn274 output1 9-cis-b-apo-10prime-carotenal nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn275 output1 CL nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn276 output1 CLA nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn277 output1 D14 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn278 output1 MAX2 nan
# v2.7.2_PIS-model-JALR-Reactions_New Conn279 output1 D53 nan

# %%
node_localisations
# Out:
# {'ER',
#  'Golgi',
#  'chloroplast',
#  'cytoplasm',
#  'extracellular',
#  'mitochondria?',
#  nan,
#  'nuc',
#  'nucleus',
#  'peroxisome',
#  'vacuole'}

# %%
new_localisation
# Out:
# {'',
#  'chloroplast',
#  'cytoplasm',
#  'endoplasmic reticulum',
#  'extracellular',
#  'golgi apparatus',
#  'nucleus',
#  'peroxisome',
#  'putative:mitochondrion',
#  'vacuole'}

# %%
len(df_edges['ConnID'].unique()) == df_edges.shape[0]
# Out:
# False

# %%
df_edges['RxID'] = df_edges.index.map(lambda x: "RxID-" + str(x))

# %%
len(df_edges['RxID'].unique()) == df_edges.shape[0]
# Out:
# True

# %%
df_edges.to_csv(os.path.join("..", "data", "raw", "edges-sheet.tsv"), sep="\t")

# %%
homologue_cols = [f"{x}_homologues" for x in all_species]

# %%
all_species
# Out:
# ['ath', 'stu', 'osa']

# %%
with open(os.path.join("..", "data", "raw", "complexes_to_add.tsv"), "w") as out:
    for c in complexes_to_add:
        out.write(f"{c}\n")

# %% [markdown]
# # END
