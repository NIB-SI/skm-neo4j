# %% [markdown]
# # Import neo4j DB: 1/4
#
# Code to translate v2.7.4_PIS-model.xlsx to neo4j database.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import re
import numpy as np
import os
from IPython.display import Image

# %%
import helpers

# %%
from importlib import reload

# %% [markdown]
# Connect to graph via docker-compose link. See http://localhost:7474/browser/

# %%
node_labels = [
    'PlantCoding',
    'PlantNonCoding',
    'PlantAbstract',
    'Complex',
    'ExternalOrganism', 
    'ExternalCoding',
    'ExternalNonCoding',
    'Process', 
    'MetaboliteFamily',
    'Metabolite',
    'GeneExpression', 
    'PseudoNode'
]

# %% [markdown]
# ## Read in sheets

# %%
input_path = os.path.join("..", "data", "raw")

# %% [markdown]
# ### Components sheet

# %%
sheets = [#(file, sheet_name)]
    ("v2.7.5_PIS-model.xlsx", "Components"),
    ("v2.7.5_PIS-model.xlsx", "Components_New"), 
    ("Model_CK.xlsx", "Components_new"), 
    ("v2.7.2_PIS-model-JALR.xlsx", "Components_New")
]

# %%
# resave xlsx as tsv
drops = ['Legacy:Process', 'mID', 'Notes', 'Unnamed: 21']
col_rename = {
    'mID':'mID', 
    'Notes':'Notes', 
    'AddedBy':'AddedBy', 
    'Species':'Species', 
    'NodeType':'NodeType', 
    'Family':'Family', 
    'Clade':'Clade', 
    'NodeID':'NodeID', 
    'NodeName':'NodeName', 
    'ModelStatus':'ModelStatus', 
    'NodeDescription':'NodeDescription', 
    'AdditionalInfo':'AdditionalInfo', 
    'ExtDBlink':'ExtDBlink', 
    'Process':'Process', 
    'ExternalDB':'ExternalDB', 
    'ModelV':'ModelV', 
    'GMM_OCD1':'GMM_OCD1', 
    'GMM_OCD':'GMM_OCD', 
    'GMM:Description':'GMM_Description', 
    'GMM:ShortName':'GMM_ShortName', 
    'GMM:Synonyms':'GMM_Synonyms', 

    'Node':'NodeName'
}

for file_name, sheet_name in sheets:
    
    print(file_name, sheet_name)
    
    file_path = os.path.join(input_path, file_name)
    
    base_name, extension = os.path.splitext(file_name)
    new_file_path = os.path.join(input_path, f'{base_name}-{sheet_name}.tsv')
    
    if os.path.exists(new_file_path):
        continue
        
    df = pd.read_excel(file_path, 
                    sheet_name=sheet_name, 
                    header=[1], 
                    dtype=str, 
                    na_values=helpers.empty_strings)
    df = df[~df["AddedBy"].isna()]
    
    to_drop = list(set(drops) & set(df.columns)) + list(df.filter(regex=("Unnamed.*")).columns)
    df.drop(to_drop, axis=1, inplace=True)
    
    new_cols = [col_rename[x] for x in df.columns]
    df.columns = new_cols
    
    df.to_csv(new_file_path, sep="\t", index=None)
# Out:
# v2.7.5_PIS-model.xlsx Components
# v2.7.5_PIS-model.xlsx Components_New
# Model_CK.xlsx Components_new
# v2.7.2_PIS-model-JALR.xlsx Components_New

# %%
dfs = []

for file_name, sheet_name in sheets:
    
    print(file_name, sheet_name)
    base_name, extension = os.path.splitext(file_name)

    file_path = os.path.join(input_path, f'{base_name}-{sheet_name}.tsv')
    
    df = pd.read_csv(file_path, sep="\t")
    
    dfs.append(df)
# Out:
# v2.7.5_PIS-model.xlsx Components
# v2.7.5_PIS-model.xlsx Components_New
# Model_CK.xlsx Components_new
# v2.7.2_PIS-model-JALR.xlsx Components_New

# %%
df_components = pd.concat(dfs, sort=False)
df_components.reset_index(drop=True, inplace=True)

# %%
pd.value_counts(df_components['NodeType'])
# Out:
# plant_coding       756
# metabolite         104
# plant coding        69
# pathogen_coding     14
# plant_abstract      12
# plant_ncRNA          8
# process              6
# plant_noncoding      4
# x                    2
# plant_complex        1
# Name: NodeType, dtype: int64

# %%
df_components[df_components['NodeType']=='x']
# Out:
#     AddedBy Species NodeType Family Clade NodeID NodeName ModelStatus  \
# 854       x       x        x      x     x      x        x           x
# 976       x       x        x      x     x      x        x           x
#
#     NodeDescription AdditionalInfo ExtDBlink Process ExternalDB ModelV  \
# 854               x              x         x     NaN          x      x
# 976               x              x         x     NaN          x      x
#
#     GMM_OCD1 GMM_OCD GMM_Description GMM_ShortName GMM_Synonyms
# 854        x       x               x             x            x
# 976        x       x               x             x            x

# %%
x = df_components[df_components['NodeType']=='x'].index; x
# Out:
# Int64Index([854, 976], dtype='int64')

# %%
df_components.drop(x, inplace=True)

# %%
df_components.loc[df_components["NodeName"].isna(), 'NodeName']
# Out:
# 830    NaN
# 831    NaN
# Name: NodeName, dtype: object

# %%
df_components.loc[df_components["NodeName"].isna(), 'NodeName'] =  df_components.loc[df_components["NodeName"].isna(), 'NodeID']

# %%
components_node_type_to_node_label = {
    "plant coding":"PlantCoding",
    "plant_coding":"PlantCoding",
    "plant_noncoding":"PlantNonCoding",
    "plant_ncRNA":"PlantNonCoding",

    "plant_complex":"Complex", 

    "metabolite":"Metabolite",

    "pathogen_coding":"ExternalCoding",
    "pathogen_noncoding":"ExternalNonCoding",
    
    "plant_abstract":"PlantAbstract",
    
    "process":"Process", 

    np.nan:"Undefined"
}

# %%
# update node labels
df_components["NodeLabel"] = df_components["NodeType"].apply(lambda x: components_node_type_to_node_label[x])
pd.value_counts(df_components['NodeLabel'])
# Out:
# PlantCoding       825
# Metabolite        104
# ExternalCoding     14
# PlantNonCoding     12
# PlantAbstract      12
# Process             6
# Undefined           1
# Complex             1
# Name: NodeLabel, dtype: int64

# %%
df_components[df_components["NodeLabel"] == "Undefined"]
# Out:
#     AddedBy Species NodeType              Family               Clade  \
# 975    JALR     osa      NaN  Class I Clp ATPase  Class I Clp ATPase
#
#             NodeID NodeName ModelStatus NodeDescription  \
# 975  Os11g0104300       D53         use             D53
#
#                                         AdditionalInfo ExtDBlink Process  \
# 975  D53 binds to the complex S-D14-MAX2 to be degr...       NaN     NaN
#
#     ExternalDB ModelV GMM_OCD1 GMM_OCD GMM_Description GMM_ShortName  \
# 975   GMM-OCDs    vNA      NaN     NaN             NaN           NaN
#
#     GMM_Synonyms  NodeLabel
# 975          NaN  Undefined

# %%
def only_asci(x):
    return "".join([character for character in x if character.isascii()])

# %%
df_components['Species'] = df_components["Species"].apply(lambda x: x.lower().strip())
df_components['observed_species'] = df_components["Species"].apply(helpers.get_second_item)
df_components['also_observed_in'] = df_components["Species"].apply(helpers.rest_of_items)


df_components["GMM_Synonyms"] = df_components["GMM_Synonyms"].apply(helpers.string_to_nice_string)
df_components['chebi_identifier'] = df_components[df_components['ExternalDB'] == "ChEBI"]["ExtDBlink"]
df_components['pubmed_identifier'] = df_components[df_components['ExternalDB'] == "PubChem"]["ExtDBlink"]
df_components['AdditionalInfo'].fillna('', inplace=True)

# %%
df_components.loc[df_components['ModelV'].isna(), 'ModelV'] = 'vNA'

# %%
df_components.loc[df_components['AddedBy'].isna(), 'AddedBy'] = 'NAN'

# %%
df_components['AddedBy'] = df_components['AddedBy'].apply(lambda x: x.upper())

# %%
df_components.loc[df_components['AddedBy']=='ZR/MZ', 'AddedBy'] = 'MZ'

# %%
df_components['AddedBy'].unique()
# Out:
# array(['KG', 'ZR', 'MZ', 'MAK', 'ŠT', 'AG', 'JALR'], dtype=object)

# %%
def only_asci(x):
    return "".join([character for character in x if character.isascii()])

def get_non_ascii(x):
    x = str(x)
    has_nonascii = False
    for character in x:
        if not character.isascii():
            has_nonascii = True
            print(character, ord(character), character.encode())
    if has_nonascii:
        print(x)
        return True
    else:
        return False

ascii_replacers = {
    b'\xc2\xa0' : b" ",           # funky WIN whitespace
    b'\xe2\x80\xa6': b'...',      # …
    b'\xe2\x80\x8b' : b'',        # have no figging clue
    b'\xe2\x80\x93' : b'-',       # –
    b'\xce\xb1' : b"alpha",       # α
    b'\xc3\x9f' : b"beta",        # ß
    b'\xce\xb2' : b"beta",        # β
    b'\xe2\x80\x98' : b"prime",   # ‘
    b'\xe2\x80\x99' : b"prime",   # ’
    b'\xc2\xb4': b'prime',        # ´
    # Sorry accents :(
    b'\xc5\xa0' : b"S",           # Š
    b'\xc5\xa1' : b's',           # š
    b'\xc5\xbd' : b'Z',           # Ž
    b'\xc4\x8d' : b'c'             # č
}


def replacer(x):
    x = x.encode('utf-8')
    for old, new in ascii_replacers.items():
        x = x.replace(old, new)
    return x.decode('utf-8')

# %%
bad_cols = []
for c in df_components.columns:
    print(c, "\n-------------")
    if any(df_components[c].apply(get_non_ascii)):
        bad_cols.append(c)
    print()
# Out:
# AddedBy
# -------------
# Š 352 b'\xc5\xa0'
# ŠT
#
# Species
# -------------
#
# NodeType
# -------------
#
# Family
# -------------
#
# Clade
# -------------
#
# NodeID
# -------------
#
# NodeName
# -------------
#
# ModelStatus
# -------------
#
# NodeDescription
# -------------
# ß 223 b'\xc3\x9f'
# 12-hydroxyjasmonic acid 12-O-ß-D-glucoside
#   160 b'\xc2\xa0'
# gibberellin 3-oxidase
# ‘ 8216 b'\xe2\x80\x98'
# N6-(dimethyallyl)adenosine 5‘-monophosphate
# ‘ 8216 b'\xe2\x80\x98'
# N6-(dimethyallyl)adenosine 5‘-diphosphate
# ‘ 8216 b'\xe2\x80\x98'
# N6-(dimethyallyl)adenosine 5‘-triphosphate
# α 945 b'\xce\xb1'
# 7-(α-D-glucosyl)-N6-isopentenyladenine
# α 945 b'\xce\xb1'
# 9-(α-D-glucosyl)-N6-isopentenyladenine
# β 946 b'\xce\xb2'
# O-β-D-glucosyl-trans-zeatin
# α 945 b'\xce\xb1'
# 9-(α-D-glucosyl)-trans-zeatin
# α 945 b'\xce\xb1'
# 7-(α-D-glucosyl)dihydrozeatin
# α 945 b'\xce\xb1'
# 9-(α-D-glucosyl)dihydrozeatin
# β 946 b'\xce\xb2'
# O-β-D-glucosyl-cis-zeatin
# β 946 b'\xce\xb2'
# 7-(β-D-glucosyl)-cis-zeatin
# β 946 b'\xce\xb2'
# 9-(β-D-glucosyl)-cis-zeatin
# α 945 b'\xce\xb1'
# UDP-α-D-glucose
#
# AdditionalInfo
# -------------
#   160 b'\xc2\xa0'
# Chitin is a polymer of N-acetyl-d-glucosamine that is a major component of fungal cell walls and has been recognized as a general elicitor of plant defense responses for many years.
#   160 b'\xc2\xa0'
# EC 2.2.1.7, ec00900
#   160 b'\xc2\xa0'
# EC 2.2.1.7, ec00900
#   160 b'\xc2\xa0'
# EC 2.2.1.7, ec00900
# ’ 8217 b'\xe2\x80\x99'
# Encodes a trans-acting siRNA (tasi-RNA) that regulates the expression of auxin response factor genes (ARF2, ARF4, ETT). One of 3 genomic loci that encode the TAS3 siRNA. | In contrast to the single mRNA binding family, TAS3 requires the guide mRNA miR390 bind the transcript at two sites. The transcript is then cleaved at the 3’ binding site only, by AGO7. As is the case for the TAS1, TAS2, and TAS3 families, RDR6 then synthesizes the dsRNA fragment which is further processed by DCL4.
#
# ExtDBlink
# -------------
#
# Process
# -------------
#
# ExternalDB
# -------------
#
# ModelV
# -------------
#
# GMM_OCD1
# -------------
#
# GMM_OCD
# -------------
#
# GMM_Description
# -------------
#
# GMM_ShortName
# -------------
#
# GMM_Synonyms
# -------------
#
# NodeLabel
# -------------
#
# observed_species
# -------------
#
# also_observed_in
# -------------
#
# chebi_identifier
# -------------
#
# pubmed_identifier
# -------------

# %%
for c in bad_cols:
    df_components[c] = df_components[c].apply(replacer)

# %%
from IPython.display import display

# %%
for label, subdf in df_components.groupby('NodeLabel'):
    dups =  subdf[subdf.duplicated(['NodeName'], keep=False)]
    if dups.shape[0] > 0:
        print(label)
        display(dups.sort_values('NodeName'))
# Out:
# Metabolite
#     AddedBy    Species    NodeType   Family Clade NodeID NodeName ModelStatus  \
# 529      MZ  plant_all  metabolite  PostROS   H2O    H2O      H2O      ignore
# 939      AG        all  metabolite      H2O   H2O    H2O      H2O         use
# 523      MZ  plant_all  metabolite   PreROS    O2     O2       O2         use
# 940      AG        all  metabolite       O2    O2     O2       O2         use
#
#             NodeDescription AdditionalInfo  ... GMM_OCD1 GMM_OCD  \
# 529                   water                 ...      NaN     NaN
# 939                   water                 ...      NaN     NaN
# 523  ROS precursors; oxygen                 ...      NaN     NaN
# 940                dioxygen                 ...      NaN     NaN
#
#     GMM_Description GMM_ShortName GMM_Synonyms   NodeLabel observed_species  \
# 529             NaN           NaN               Metabolite        plant_all
# 939             NaN           NaN               Metabolite              all
# 523             NaN           NaN               Metabolite        plant_all
# 940             NaN           NaN               Metabolite              all
#
#     also_observed_in chebi_identifier pubmed_identifier
# 529                               NaN               NaN
# 939                               NaN               NaN
# 523                       CHEBI:25805               NaN
# 940                               NaN               NaN
#
# [4 rows x 24 columns]
# PlantCoding
#     AddedBy Species      NodeType  Family   Clade              NodeID  \
# 803     MAK     ath  plant_coding     CPS     CPS           AT4G02780
# 826     MAK     stu  plant_coding     CPS     CPS  Sotub06g034690.1.1
# 808     MAK     ath  plant_coding  GA20ox  GA20ox           AT4G25420
# 828     MAK     stu  plant_coding  GA20ox  GA20ox  Sotub03g007160.1.1
# 810     MAK     ath  plant_coding  GA20ox  GA20ox           AT5G07200
# 827     MAK     stu  plant_coding  GA20ox  GA20ox  Sotub11g029030.1.1
# 811     MAK     ath  plant_coding  GA20ox  GA20ox           AT1G60980
# 829     MAK     stu  plant_coding  GA20ox  GA20ox  Sotub01g031210.1.1
# 840     MAK     ath  plant_coding     MYB   GAMYB           AT5G06100
# 846     MAK     stu  plant_coding     MYB   GAMYB  Sotub06g030530.1.1
#
#     NodeName ModelStatus                   NodeDescription  \
# 803      CPS         use  ent-copalyl diphosphate synthase
# 826      CPS         use  ent-copalyl diphosphate synthase
# 808  GA20ox1         use            gibberellin 20-oxidase
# 828  GA20ox1         use            gibberellin 20-oxidase
# 810  GA20ox3         use            gibberellin 20-oxidase
# 827  GA20ox3         use            gibberellin 20-oxidase
# 811  GA20ox4         use            gibberellin 20-oxidase
# 829  GA20ox4         use            gibberellin 20-oxidase
# 840    MYB33         use            gibberellin induced TF
# 846    MYB33         use            gibberellin induced TF
#
#                          AdditionalInfo  ...        GMM_OCD1  \
# 803  also known as GA REQUIRING 1 (GA1)  ...  OCD_all_001702
# 826  also known as GA REQUIRING 1 (GA1)  ...             NaN
# 808                                      ...  OCD_all_000842
# 828                                      ...             NaN
# 810                                      ...  OCD_all_023006
# 827                                      ...             NaN
# 811                                      ...  OCD_all_023006
# 829                                      ...             NaN
# 840                                      ...  OCD_all_003344
# 846                                      ...             NaN
#
#                                                GMM_OCD  \
# 803  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 826                                                NaN
# 808  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 828                                                NaN
# 810  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 827                                                NaN
# 811  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 829                                                NaN
# 840  http://www.gomapman.org/ortholog/OCD_all/OCD_a...
# 846                                                NaN
#
#                                        GMM_Description GMM_ShortName  \
# 803  Terpenoid cyclases/Protein prenyltransferases ...           GA1
# 826                                                NaN           NaN
# 808  2-oxoglutarate (2OG) and Fe(II)-dependent oxyg...       GA20OX1
# 828                                                NaN           NaN
# 810                           gibberellin 20-oxidase 3       GA20OX3
# 827                                                NaN           NaN
# 811                           gibberellin 20-oxidase 4       GA20OX4
# 829                                                NaN           NaN
# 840                              myb domain protein 33         MYB33
# 846                                                NaN           NaN
#
#                          GMM_Synonyms    NodeLabel observed_species  \
# 803  ABC33,ATCPS1,CPS,CPS1,GA1,TPSGA1  PlantCoding              ath
# 826                                    PlantCoding              stu
# 808          20ox1,At2301,GA20OX1,GA5  PlantCoding              ath
# 828                                    PlantCoding              stu
# 810    20ox3,ATGA20OX3,GA20OX3,YAP169  PlantCoding              ath
# 827                                    PlantCoding              stu
# 811                 ATGA20OX4,GA20OX4  PlantCoding              ath
# 829                                    PlantCoding              stu
# 840                     ATMYB33,MYB33  PlantCoding              ath
# 846                                    PlantCoding              stu
#
#     also_observed_in chebi_identifier pubmed_identifier
# 803                               NaN               NaN
# 826                               NaN               NaN
# 808                               NaN               NaN
# 828                               NaN               NaN
# 810                               NaN               NaN
# 827                               NaN               NaN
# 811                               NaN               NaN
# 829                               NaN               NaN
# 840                               NaN               NaN
# 846                               NaN               NaN
#
# [10 rows x 24 columns]

# %%
# remove duplicated metabolites
df_components.drop([939, 940], inplace=True)

# %%
path = os.path.join(input_path, 'parsed-components.tsv')
df_components.to_csv(path, sep="\t", index=None)
print(path)
# Out:
# ../data/raw/parsed-components.tsv

# %%
# !head $path
# Out:
# AddedBy	Species	NodeType	Family	Clade	NodeID	NodeName	ModelStatus	NodeDescription	AdditionalInfo	ExtDBlink	Process	ExternalDB	ModelV	GMM_OCD1	GMM_OCD	GMM_Description	GMM_ShortName	GMM_Synonyms	NodeLabel	observed_species	also_observed_in	chebi_identifier	pubmed_identifier
# KG	ath	plant_coding	SAM	SAMS	AT1G02500	SAM1	use	SAM synthetase [EC:2.5.1.6]		OCD_all_000621	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000621	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000621	S-adenosylmethionine synthetase 1	SAM1	AtSAM1,MAT1,METK1,SAM-1,SAM1	PlantCoding	ath
# KG	ath	plant_coding	SAM	SAMS	AT4G01850	SAM2	use	SAM synthetase [EC:2.5.1.6]		OCD_all_000621	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000621	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000621	S-adenosylmethionine synthetase 2	SAM2	AtSAM2,MAT2,SAM-2,SAM2	PlantCoding	ath
# KG	ath	plant_coding	SAM	SAMS	AT2G36880	SAM3	use	SAM synthetase [EC:2.5.1.6]		OCD_all_000621	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000621	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000621	methionine adenosyltransferase 3	METK3	MAT3,METK3	PlantCoding	ath
# KG	ath	plant_coding	SAM	SAMS	AT3G17390	SAM4	use	SAM synthetase [EC:2.5.1.6]		OCD_all_000621	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000621	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000621	S-adenosylmethionine synthetase family protein	METK4	MAT4,METK4,MTO3,SAMS3	PlantCoding	ath
# KG	ath	plant_coding	ACS	ACS1,2,6	AT3G61510	ACS1	use	ACC synthase [EC:4.4.1.14]		OCD_all_000133	Hormone:ET	GMM-OCDs	v2.5	OCD_all_000133	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000133	ACC synthase 1	ACS1	ACC2,ACS1,AT-ACS1	PlantCoding	ath
# KG	ath	plant_coding	ACS	ACS1,2,6	AT1G01480	ACS2	use	ACC synthase [EC:4.4.1.14]		OCD_all_000133	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000133	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000133	1-amino-cyclopropane-1-carboxylate synthase 2	ACS2	ACC1,ACS2,AT-ACC2	PlantCoding	ath
# KG	ath	plant_coding	ACS	ACS4,5,8,9,11	AT2G22810	ACS4	use	ACC synthase [EC:4.4.1.14]		OCD_all_000133	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000133	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000133	1-aminocyclopropane-1-carboxylate synthase 4	ACS4	ACC4,ACS4,ATACS4	PlantCoding	ath
# KG	ath	plant_coding	ACS	ACS4,5,8,9,11	AT5G65800	ACS5	use	ACC synthase [EC:4.4.1.14]		OCD_all_000133	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000133	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000133	ACC synthase 5	ACS5	ACC5,ACS5,ATACS5,CIN5,ETO2	PlantCoding	ath
# KG	ath	plant_coding	ACS	ACS1,2,6	AT4G11280	ACS6	use	ACC synthase [EC:4.4.1.14]		OCD_all_000133	Hormone:ET	GMM-OCDs	v1.0	OCD_all_000133	http://www.gomapman.org/ortholog/OCD_all/OCD_all_000133	1-aminocyclopropane-1-carboxylic acid (acc) synthase 6	ACS6	ACC6,ACS6,ATACS6	PlantCoding	ath

# %% [markdown]
# # END

# %% [markdown]
# ## Components summary

# %%
q = '''MATCH (n) RETURN DISTINCT n.name AS name, n.level AS level'''
nodes = graph.run(q).data()
all_nodes_in_components = set([(d["name"], d["level"]) for d in nodes])

# %%
len(all_nodes_in_components)
# Out:
# 245

# %%
sorted(df_components['NodeLabel'].unique())
# Out:
# ['Complex',
#  'ExternalCoding',
#  'Metabolite',
#  'PlantAbstract',
#  'PlantCoding',
#  'PlantNonCoding',
#  'Process']

# %%
node_dict = {}
for label in node_labels:
    q = '''MATCH (n:%s) RETURN DISTINCT n.name'''%label
    s = set([d['n.name'] for d in graph.run(q).data()])
    print(label, len(s))
    node_dict[label] = s
# Out:
# PlantCoding 142
# PlantNonCoding 9
# PlantAbstract 7
# Complex 1
# ExternalOrganism 3
# ExternalCoding 14
# ExternalNonCoding 0
# Process 6
# MetaboliteFamily 4
# Metabolite 59

# %% [markdown]
# ### Reactions sheet

# %%
df_edges_orig = pd.read_excel(input_path, 
                         sheet_name="Reactions", 
                         header=[1], 
                         dtype=str, 
                         na_values=helpers.empty_strings)
df_edges_orig = df_edges_orig[df_edges_orig['Status'].isin(["forCB", "forCB_INVENTED"])]
df_edges_orig.drop(['Status', 'FOXMES', 'Legacy:Process', 'Legacy:ReactionMode'], axis=1, inplace=True)
df_edges_orig.columns = pd.Index(['AddedBy', 'ConnID', 'Species', 
          'input1_ID', 'input1_level', 'input1_localisation', 'input1_type', 
          'input2_ID', 'input2_level', 'input2_localisation', 'input2_type', 
          'input3_ID', 'input3_level', 'input3_localisation', 'input3_type', 
          'ReactionEffect', 'ReactionMode', 'Modifications',
          'output1_ID', 'output1_level', 'output1_localisation', 'output1_type', 
          'TrustLevel', 'Literature', 'AdditionalInfo', 'Comment', 'ModelV', 'kinetics'],
      dtype='object')

df_edges_new = pd.read_excel(input_path, 
                         sheet_name="Reactions_New", 
                         header=[1], 
                         dtype=str, 
                         na_values=helpers.empty_strings)
df_edges_new = df_edges_new[~df_edges_new['AddedBy'].isin(['-'])]
df_edges_new.drop(['Status'], axis=1, inplace=True)
df_edges_new.columns = pd.Index(['AddedBy', 'ConnID', 'Species', 
          'input1_ID', 'input1_level', 'input1_type', 
          'input2_ID', 'input2_level', 'input2_type', 
          'input3_ID', 'input3_level', 'input3_type',                                  
          'ReactionEffect', 'ReactionMode', 
          'output1_ID', 'output1_level', 'output1_type', 
          'TrustLevel', 'Literature', 'AdditionalInfo', 'Comment', 'ModelV'],
      dtype='object')


df_edges = pd.concat([df_edges_orig, df_edges_new], sort=False)

# %%
df_edges = df_edges[~df_edges["AddedBy"].isna()]

# %%
df_edges.tail()
# Out:
#      AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 46        sb  Conn310     ath       CAT       family                 NaN
# 47        sb  Conn310     ath        SA         node                 NaN
# 48        sb  Conn310     ath      CAT2         node                 NaN
# 49        sb  Conn310     ath      CAT2         node                 NaN
# 1737       x        x       x         x            x                 NaN
#
#        input1_type input2_ID input2_level input2_localisation  ... output1_ID  \
# 46    plant_coding      LSD1         node                 NaN  ...        NaN
# 47      metabolite      CAT2         node                 NaN  ...        NaN
# 48    plant_coding      ACX2         node                 NaN  ...        NaN
# 49    plant_coding      ACX3         node                 NaN  ...        NaN
# 1737             x       NaN            x                 NaN  ...          x
#
#      output1_level output1_localisation output1_type  \
# 46             NaN                  NaN          NaN
# 47             NaN                  NaN          NaN
# 48             NaN                  NaN          NaN
# 49             NaN                  NaN          NaN
# 1737             x                  NaN            x
#
#                                        TrustLevel  \
# 46    [R1] targetted experiments (e.g. Y2H, BIFC)
# 47                         [R4] indirect reaction
# 48    [R1] targetted experiments (e.g. Y2H, BIFC)
# 49    [R1] targetted experiments (e.g. Y2H, BIFC)
# 1737                                            x
#
#                           Literature  \
# 46         DOI:10.1104/pp.113.225805
# 47    DOI:10.1016/j.chom.2017.01.007
# 48    DOI:10.1016/j.chom.2017.01.007
# 49    DOI:10.1016/j.chom.2017.01.007
# 1737                               x
#
#                                          AdditionalInfo Comment ModelV  \
# 46    LSD1 interacted with all three catalases both ...     NaN    vNA
# 47    SA decreased CAT2 activity in a dose-dependent...     NaN    vNA
# 48    CAT2 Promotes the Activityof ACX2/ACX3 ( (test...     NaN    vNA
# 49    CAT2 Promotes the Activityof ACX2/ACX3 ( (test...     NaN    vNA
# 1737                                                  x       x      x
#
#      kinetics
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 1737      NaN
#
# [5 rows x 28 columns]

# %%
x = df_edges[df_edges['AddedBy']=='x'].index
print(x)
df_edges.drop(x, inplace=True)
# Out:
# Int64Index([1737], dtype='int64')

# %%
df_edges["TrustLevel"].unique()
# Out:
# array(['[R1] targetted experiments (e.g. Y2H, BIFC)',
#        '[Ry] invented reaction', '[Rx] incomplete/unspecific reaction',
#        '[R2] high-throughput experiment (e.g. ChIP-seq)',
#        '[R3] in-silico prediction', '[R4] indirect reaction'],
#       dtype=object)

# %%
df_edges['trust_level']  = df_edges["TrustLevel"].apply(lambda x: re.search( r"(R[1|2|3|4|x|y]|undefined)", x).groups()[0])
df_edges['observed_species'] = df_edges["Species"].apply(helpers.get_second_item)
df_edges['also_observed_in'] = df_edges["Species"].apply(helpers.rest_of_items)
df_edges['Comment'] = df_edges['Comment'].fillna("")
df_edges['AdditionalInfo'] = df_edges['AdditionalInfo'].fillna("")

# %%
df_edges['AddedBy'] = df_edges['AddedBy'].apply(lambda x: x.upper())
df_edges["AddedBy"].unique()
# Out:
# array(['KG', 'MZ', 'ZR', 'MPE', 'ACR', 'MAK', 'ŠT', 'SB'], dtype=object)

# %%
df_edges.loc[df_edges['ModelV'].isna(), 'ModelV'] = 'vNA'
df_edges['ModelV'].unique()
# Out:
# array(['v1.0', 'v2.5', 'v2.7', 'v2.6', 'vNA'], dtype=object)

# %%
def doi_list(x):
    x = only_asci(x.lower())
    match = re.findall("(?:doi)(?:\:|\/)\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["doi:" + m.rstrip('.') for m in match]
    else:
        return []

def pubmed_list(x):
    x = only_asci(x.lower())
    match = re.findall("(?:pmid)\:\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["pmid:" + m.rstrip('.') for m in match]
    else:
        return []

def list_to_string(x):
    return ",".join([str(i) for i in x])

# %%
# format literature sources
df_edges["Literature"].fillna(value="", inplace=True)
for i, row in df_edges.iterrows():
    s = row['Literature']
    source = doi_list(s)
    source += pubmed_list(s)
    for z in s.split("|"):
        key = z.lower()
        if ":" in key:
            if "aracyc" in key:
                aracyc_string = "aracyc:" + z.split(":")[1].strip()
                source.append(aracyc_string)
            elif "kegg" in key:
                kegg_string = "kegg:" + z.split(":")[1].strip()
                source.append(kegg_string)
            elif "doi" in key:
                # already fetched
                continue
            elif ("pubmed" in key) or ("pmid" in key):
                pmid_string = "pubmed:" + z.split(":")[1].strip()
        elif "invented" in key:
            source.append("invented")
        else:
            print("no/bad reference", row["ConnID"], z)
            source.append("other:" + only_asci(z.strip()))
    if len(source) > 0:
        df_edges.loc[i, "literature_sources"] = list_to_string(source)
    else:
        print(row["ConnID"], z)
# Out:
# no/bad reference Conn040
# no/bad reference Conn118
# no/bad reference Conn120
# no/bad reference Conn122
# no/bad reference Conn182
# no/bad reference Conn183
# no/bad reference Conn199 ? Kg need to find reference
# no/bad reference Conn273 KEGG
# no/bad reference Conn274 KEGG
# no/bad reference Conn275 KEGG
# no/bad reference Conn276 KEGG
# no/bad reference Conn276  10.1073/pnas.98.4.2065
# no/bad reference Conn277 KEGG
# no/bad reference Conn278 KEGG
# no/bad reference Conn279 KEGG
# no/bad reference Conn280 KEGG
# no/bad reference Conn281 KEGG
# no/bad reference Conn282 KEGG
# no/bad reference Conn283 KEGG
# no/bad reference Conn309

# %%
df_edges[["ConnID", "Literature", "literature_sources"]].to_csv("lit-check.tsv", sep="\t", index=None)

# %%
df_edges.reset_index(inplace=True, drop=True)

# %%
save_df = df_edges.copy()
#df_edges = save_df.copy()

# %%
df_edges[df_edges['ConnID'].duplicated()]
# Out:
#     AddedBy   ConnID Species            input1_ID      input1_level  \
# 74       KG  Conn080     ath  Trichome-initiation            family
# 260     MAK      NaN     ath            GID1a,b,c  clade/orthologue
# 261     MAK      NaN     ath            GID1a,b,c  clade/orthologue
# 268     MAK      NaN     ath             GA1-GID1            family
# 269     MAK      NaN     ath             GA3-GID1            family
# 270     MAK      NaN     ath             GA4-GID1            family
# 271     MAK      NaN     ath                 SLY1              node
# 272     MAK      NaN     osa                 GID2              node
# 273     MAK      NaN     ath       GA1-GID1-DELLA            family
# 274     MAK      NaN     osa        GA1-GID1-SLR1            family
# 287      SB  Conn310     ath                   SA              node
# 288      SB  Conn310     ath                 CAT2              node
# 289      SB  Conn310     ath                 CAT2              node
#
#     input1_localisation    input1_type  input2_ID input2_level  \
# 74                  NaN        process  potyvirus       family
# 260                 NaN   plant_coding        GA3       family
# 261                 NaN   plant_coding        GA4       family
# 268                 NaN  plant_complex      DELLA       family
# 269                 NaN  plant_complex      DELLA       family
# 270                 NaN  plant_complex      DELLA       family
# 271                 NaN   plant_coding        SCF       family
# 272                 NaN   plant_coding        SCF       family
# 273                 NaN  plant_complex   SCF-SLY1       family
# 274                 NaN  plant_complex   SCF-GID2       family
# 287                 NaN     metabolite       CAT2         node
# 288                 NaN   plant_coding       ACX2         node
# 289                 NaN   plant_coding       ACX3         node
#
#     input2_localisation  ...                                   TrustLevel  \
# 74                  NaN  ...                       [Ry] invented reaction
# 260                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 261                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 268                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 269                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 270                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 271                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 272                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 273                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 274                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 287                 NaN  ...                       [R4] indirect reaction
# 288                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 289                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                             Literature  \
# 74   DOI:10.1105/tpc.111.083261 (Qi, 2011: The jasm...
# 260                         DOI:10.1105/tpc.106.047415
# 261                         DOI:10.1105/tpc.106.047415
# 268                          DOI:10.1104/pp.112.200956
# 269                          DOI:10.1104/pp.112.200956
# 270                          DOI:10.1104/pp.112.200956
# 271                             DOI:10.1105/tpc.010827
# 272                        DOI:10.1126/science.1081077
# 273  DOI:10.1104/pp.112.200956 | DOI:10.1105/tpc.01...
# 274  DOI:10.1104/pp.112.200956 | https://doi.org/10...
# 287                     DOI:10.1016/j.chom.2017.01.007
# 288                     DOI:10.1016/j.chom.2017.01.007
# 289                     DOI:10.1016/j.chom.2017.01.007
#
#                                         AdditionalInfo Comment ModelV  \
# 74                                                               v2.7
# 260                                                               vNA
# 261                                                               vNA
# 268                                                               vNA
# 269                                                               vNA
# 270                                                               vNA
# 271                                                               vNA
# 272                                                               vNA
# 273                                                               vNA
# 274                                                               vNA
# 287  SA decreased CAT2 activity in a dose-dependent...            vNA
# 288  CAT2 Promotes the Activityof ACX2/ACX3 ( (test...            vNA
# 289  CAT2 Promotes the Activityof ACX2/ACX3 ( (test...            vNA
#
#     kinetics trust_level observed_species also_observed_in  \
# 74       NaN          Ry              ath
# 260      NaN          R1              ath
# 261      NaN          R1              ath
# 268      NaN          R1              ath
# 269      NaN          R1              ath
# 270      NaN          R1              ath
# 271      NaN          R1              ath
# 272      NaN          R1              osa
# 273      NaN          R1              ath
# 274      NaN          R1              osa
# 287      NaN          R4              ath
# 288      NaN          R1              ath
# 289      NaN          R1              ath
#
#                                    literature_sources
# 74                         doi:10.1105/tpc.111.083261
# 260                        doi:10.1105/tpc.106.047415
# 261                        doi:10.1105/tpc.106.047415
# 268                         doi:10.1104/pp.112.200956
# 269                         doi:10.1104/pp.112.200956
# 270                         doi:10.1104/pp.112.200956
# 271                            doi:10.1105/tpc.010827
# 272                       doi:10.1126/science.1081077
# 273  doi:10.1104/pp.112.200956,doi:10.1105/tpc.010827
# 274                         doi:10.1104/pp.112.200956
# 287                    doi:10.1016/j.chom.2017.01.007
# 288                    doi:10.1016/j.chom.2017.01.007
# 289                    doi:10.1016/j.chom.2017.01.007
#
# [13 rows x 32 columns]

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.           v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.           v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.           v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...           v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...           v1.0      NaN
#
#   trust_level observed_species also_observed_in  \
# 0          R1              ath
# 1          R1              ath
# 2          R1              ath
# 3          R1              ath
# 4          R1              ath
#
#                                   literature_sources
# 0                  doi:10.1042/bj20120245,other:KEGG
# 1                  doi:10.1042/bj20120245,other:KEGG
# 2                  doi:10.1042/bj20120245,other:KEGG
# 3  doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                  doi:10.1042/bj20120245,other:KEGG
#
# [5 rows x 32 columns]

# %%
for x in ['input1', 'input2', 'input3', 'output1']:
    df_edges.loc[:, x + "_ID"] = df_edges[x + "_ID"].apply(helpers.reorder_ids)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.           v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.           v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.           v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...           v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...           v1.0      NaN
#
#   trust_level observed_species also_observed_in  \
# 0          R1              ath
# 1          R1              ath
# 2          R1              ath
# 3          R1              ath
# 4          R1              ath
#
#                                   literature_sources
# 0                  doi:10.1042/bj20120245,other:KEGG
# 1                  doi:10.1042/bj20120245,other:KEGG
# 2                  doi:10.1042/bj20120245,other:KEGG
# 3  doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                  doi:10.1042/bj20120245,other:KEGG
#
# [5 rows x 32 columns]

# %%
def convert_node_to_family(x):
    # pathogen proteins are listed as proteins, so cannot use dict
    id_, type_, level_ = x.values
      
    if id_ is np.nan:
        return np.nan, np.nan

    new_label = None
    family_id = None
    
    ########################
    # Simple Cases
    ########################
    if type_ in ['complex', 'complex [active]', 'complex [activated]', 'complex [inactive]', 'plant_complex']:
        if not (id_ in node_dict["Complex"]):
            complexes_to_add.append(id_)
        new_label = 'Complex'
        family_id = id_
    
    elif type_ in ["metabolite"]:
        for label in ["Metabolite", "MetaboliteFamily"]:
            if id_ in node_dict[label]:
                new_label = label
                break
        if not new_label:
            missing_in_components.update([id_])        
            print(id_, type_, level_, " | (label) not a listed metabolite")
        family_id = id_

    elif type_ in ['process']:
        if (id_ in node_dict["Process"]):
            family_id = id_
            new_label = "Process"
        else:
            print(id_, type_, level_, " | (label) process not a listed process")
        
    else:
        ########################
        # family ID
        ########################
        check_external = False
        if level_ == "family":    
            family_id = id_
        elif level_ in ["clade", "clade/orthologue"]:
            try:
                family_id = clade_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        elif level_ == "node":
            try:
                family_id = node_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        
        if check_external:
            for label in ["ExternalOrganism", "ExternalCoding", "ExternalNonCoding"]:
                if id_ in node_dict[label]:
                    new_label = label
                    family_id = id_
                    break
                    
        if not family_id:
            print(id_, type_, level_, " | (family id) could not convert to family/external")
                
        ########################
        # Label
        ########################
        if (family_id) and (not new_label):
            id_labels = [] #looping just in case an id occurs mutiple times
            for label in node_labels:
                if family_id in node_dict[label]:
                    id_labels.append(label)

            if len(id_labels) == 1:
                new_label = id_labels[0]
            elif len(id_labels) > 1:
                print(id_, type_, level_, " | (label) many labels fit")
                missing_in_components.update([id_])       

            else:
                print(id_, type_, level_, " | (label) could not find label")
                missing_in_components.update([id_])        

    return family_id, new_label

# %%
complexes_to_add = []
missing_in_components = set()
replace_w_family = set()

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, level_col, new_id, new_label_col  =\
            [prefix + x for x in ('_ID',  '_type',  '_level',  '_newID', '_label')]    
    
    df_edges[[new_id, new_label_col]] = df_edges[[id_col, type_col, level_col]].apply(convert_node_to_family, axis=1, result_type='expand')
# Out:
# miR6022 plant_ncRNA node  | (family id) could not convert to family/external
# LSD1 plant_coding node  | (family id) could not convert to family/external

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   also_observed_in                                 literature_sources  \
# 0                                   doi:10.1042/bj20120245,other:KEGG
# 1                                   doi:10.1042/bj20120245,other:KEGG
# 2                                   doi:10.1042/bj20120245,other:KEGG
# 3                   doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                                   doi:10.1042/bj20120245,other:KEGG
#
#   input1_newID input1_label input2_newID input2_label input3_newID  \
# 0        L-Met   Metabolite          SAM  PlantCoding          NaN
# 1         SAMe   Metabolite          ACS  PlantCoding          NaN
# 2          ACC   Metabolite          ACO  PlantCoding          NaN
# 3         Cu2+   Metabolite          HMA  PlantCoding          NaN
# 4          ETR  PlantCoding         Cu2+   Metabolite          NaN
#
#   input3_label output1_newID output1_label
# 0          NaN          SAMe    Metabolite
# 1          NaN           ACC    Metabolite
# 2          NaN            ET    Metabolite
# 3          NaN          Cu2+    Metabolite
# 4          NaN           ETR   PlantCoding
#
# [5 rows x 40 columns]

# %%
def get_orthologues(x, prefix=""):
    id_, level_, label_ = x.values
    ########################
    # Specie specific homologues
    ########################
    
    return_D = {f"{prefix}_{specie}_homologues":"" for specie in all_species}
    
    if label_ in ['PlantCoding', 'PlantNonCoding',  'PlantAbstract']:

        for species in all_species:
            species = f"{species}_homologues"
            k = f"{prefix}_{species}"
            if level_ == 'node':
                return_D[k] = node_ids_key[species][id_]
            elif level_ == 'clade':
                return_D[k] =  clade_ids_key[species][id_]
            elif level_ == 'family':
                return_D[k] =  family_ids_key[species][id_]

    return_D = {x:helpers.list_to_string(list(return_D[x])) for x in return_D}
    return return_D

# %%
new_dfs = []
for prefix in ['input1', 'input2', 'input3', 'output1']:
    print(prefix)
    id_col, level_col, new_label_col  =\
                [prefix + x for x in ('_ID',  '_level',  '_label')]        
    
    new_df = df_edges[[id_col, level_col, new_label_col ]].apply(get_orthologues, axis=1, result_type='expand', prefix=prefix)
    new_dfs.append(new_df)
    #df_edges = df_edges.join(new_df, sort=False)
# Out:
# input1
# input2
# input3
# output1

# %%
homologues_df = pd.concat(new_dfs, sort=False, axis=1)

# %%
homologues_df.loc[0]
# Out:
# input1_ath_homologues
# input1_osa_homologues
# input1_stu_homologues
# input2_ath_homologues     AT2G36880,AT1G02500,AT4G01850,AT3G17390
# input2_osa_homologues
# input2_stu_homologues
# input3_ath_homologues
# input3_osa_homologues
# input3_stu_homologues
# output1_ath_homologues
# output1_osa_homologues
# output1_stu_homologues
# Name: 0, dtype: object

# %%
df_edges = df_edges.join(homologues_df, sort=False)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input1_stu_homologues                              input2_ath_homologues  \
# 0                                  AT2G36880,AT1G02500,AT4G01850,AT3G17390
# 1                        AT5G65800,AT5G51690,AT4G26200,AT3G49700,AT1G01...
# 2                        AT1G62380,AT1G12010,AT1G77330,AT1G05010,AT2G19590
# 3                                  AT5G44790,AT5G21930,AT4G33520,AT1G63440
# 4
#
#   input2_osa_homologues input2_stu_homologues input3_ath_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#   input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT2G40940,AT1G66340,AT3G23150,AT1G04310,AT3G04580
#
#   output1_stu_homologues
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 52 columns]

# %%
node_type_to_node_form_dict = {
    "gene":"gene",
    
    "protein":"protein",
    "protein [activated]":"protein_active",
    'protein [active]': "protein_active",
    
    "ncRNA":"ncRNA",
    "plant_ncRNA":"ncRNA",
    'ta-siRNA':"ta-siRNA", 
        
    "complex":"complex", 
    "plant_complex":"complex",
    'complex [active]': "complex_active",
    
    "metabolite":"metabolite",
    
    "process":"process", 
    'process [active]':"process_active",

    np.nan:"", 
    "plant_coding":"unknown"
}

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, new_form_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_form')]
    
    x = df_edges[[id_col, type_col]].dropna(how='all')
    
    print(prefix)
    df_edges[new_form_col] = df_edges[type_col].apply(lambda x: node_type_to_node_form_dict[x])
# Out:
# input1
# input2
# input3
# output1

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input3_ath_homologues input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT2G40940,AT1G66340,AT3G23150,AT1G04310,AT3G04580
#
#   output1_stu_homologues input1_form     input2_form input3_form  \
# 0                         metabolite  protein_active
# 1                         metabolite  protein_active
# 2                         metabolite  protein_active
# 3                         metabolite         protein
# 4                            protein      metabolite
#
#      output1_form
# 0      metabolite
# 1      metabolite
# 2      metabolite
# 3      metabolite
# 4  protein_active
#
# [5 rows x 56 columns]

# %%
node_localisation_dict = {
    'nuc':'nucleus',
    'er':'endoplasmic reticulum',
    'golgi':'golgi apparatus'
}


good_localisations = set([
     'nucleus',
     'nucleolus',
     'cytoplasm',
     'vacuole',
     'endoplasmic reticulum',
     'chloroplast',
     'mitochondrion',
     'golgi apparatus',
     'peroxisome',
     'apoplast',
     'extracellular'
])


def node_localisation_std(x):
    if not type(x) == str:
        return ""
    
    x = x.lower()
    if x in node_localisation_dict.keys():
        x = node_localisation_dict[x]
    
    if x in good_localisations:
        return x
    else:
        return ""

node_localisations = set()
new_localisation = set()
for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, localisation_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_localisation')]
    
    x = df_edges[['ConnID', id_col, localisation_col]].dropna(how='all', subset=[ id_col, localisation_col])
    
    #for _, y in x.iterrows():
    #    if y[localisation_col] in ['mitochondria?', np.nan]:
    #        print(y['ConnID'], "\t", y[id_col], "\t", y[localisation_col])
    
    
    node_localisations.update(x[localisation_col])
    
    #print(prefix)
    df_edges[localisation_col] = df_edges[localisation_col].apply(node_localisation_std)
    
    new_localisation.update(df_edges[localisation_col])

# %%
node_localisations
# Out:
# {'ER',
#  'Golgi',
#  'chloroplast',
#  'cytoplasm',
#  'extracellular',
#  'mitochondria?',
#  nan,
#  'nuc',
#  'nucleus',
#  'peroxisome',
#  'vacuole'}

# %%
new_localisation
# Out:
# {'',
#  'chloroplast',
#  'cytoplasm',
#  'endoplasmic reticulum',
#  'extracellular',
#  'golgi apparatus',
#  'nucleus',
#  'peroxisome',
#  'vacuole'}

# %%
df_edges.to_csv(os.path.join("..", "data", "raw", "edges-sheet.tsv"), sep="\t")

# %%
homologue_cols = [f"{x}_homologues" for x in all_species]

# %%
all_species
# Out:
# ['ath', 'stu', 'osa']

# %%
with open(os.path.join("..", "data", "raw", "complexes_to_add.tsv"), "w") as out:
    for c in complexes_to_add:
        out.write(f"{c}\n")
