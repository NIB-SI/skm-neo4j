# %% [markdown]
# # Import neo4j DB: 2/4
#
# Code to translate v2.7.4_PIS-model.xlsx to neo4j database.

# %%
# check number families, nodes, clades

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import re
import numpy as np
import os
from IPython.display import Image

# %%
from py2neo import Graph, Node, Relationship

# %%
import helpers

# %%
from importlib import reload

# %% [markdown]
# Connect to graph via docker-compose link. See http://localhost:7474/browser/

# %%
graph = Graph(host="neo4j")

# %%
q = graph.run("MATCH (n) RETURN n LIMIT 10")

# %%
q.stats()
# Out:
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0

# %%
node_labels = [
    'PlantCoding',
    'PlantNonCoding',
    'PlantAbstract',
    'Complex',
    'ExternalOrganism', 
    'ExternalCoding',
    'ExternalNonCoding',
    'Process', 
    'MetaboliteFamily',
    'Metabolite',
    'GeneExpression', 
    'PseudoNode'
]

# %%
# start from scratch
graph.delete_all()

for l in node_labels:
    try:
        graph.schema.drop_uniqueness_constraint(l, "name")
    except:
        pass

# %% [markdown]
# ## Constraints on node names
#
# Constraint automatically adds an index.

# %%
for label in node_labels:
    q = f'''CREATE CONSTRAINT unique_name_{label.lower()}
        ON (node:{label}) ASSERT node.name IS UNIQUE'''
    qr = graph.run(q)
    print(label, qr.stats()['constraints_added'], qr.stats()['indexes_added'])
# Out:
# PlantCoding 1 0
# PlantNonCoding 1 0
# PlantAbstract 1 0
# Complex 1 0
# ExternalOrganism 1 0
# ExternalCoding 1 0
# ExternalNonCoding 1 0
# Process 1 0
# MetaboliteFamily 1 0
# Metabolite 1 0
# GeneExpression 1 0
# PseudoNode 1 0

# %% [markdown]
# ## Read in

# %%
input_path = os.path.join("..", "data", "raw")
path = os.path.join(input_path, 'parsed-components.tsv')

df_components = pd.read_csv(path, sep="\t")

# %% [markdown]
# ## metabolites

# %%
label = 'Metabolite'
df_metabolites = df_components[df_components['NodeLabel'] == label].copy()

# %%
df_metabolites.columns
# Out:
# Index(['AddedBy', 'Species', 'NodeType', 'Family', 'Clade', 'NodeID',
#        'NodeName', 'ModelStatus', 'NodeDescription', 'AdditionalInfo',
#        'ExtDBlink', 'Process', 'ExternalDB', 'ModelV', 'GMM_OCD1', 'GMM_OCD',
#        'GMM_Description', 'GMM_ShortName', 'GMM_Synonyms', 'NodeLabel',
#        'observed_species', 'also_observed_in', 'chebi_identifier',
#        'pubmed_identifier'],
#       dtype='object')

# %%
df_metabolites[df_metabolites['NodeName'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [AddedBy, Species, NodeType, Family, Clade, NodeID, NodeName, ModelStatus, NodeDescription, AdditionalInfo, ExtDBlink, Process, ExternalDB, ModelV, GMM_OCD1, GMM_OCD, GMM_Description, GMM_ShortName, GMM_Synonyms, NodeLabel, observed_species, also_observed_in, chebi_identifier, pubmed_identifier]
# Index: []
#
# [0 rows x 24 columns]

# %%
want_columns = ['AddedBy', 'Family',
       'NodeID', 'NodeName', 'NodeDescription',
       'AdditionalInfo', 'Process', 'ExternalDB', 'ModelV',
       'GMM_OCD1', 'GMM_OCD', 'GMM_Description', 'GMM_ShortName',
       'GMM_Synonyms', 'chebi_identifier', 'pubmed_identifier']

# %%
f = '%s-components.tsv'%label
df_metabolites[want_columns].to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.component_node_query(f, label, 
                     n_name="line.NodeName"
                    )

# %%
df_metabolites[df_metabolites['NodeName'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [AddedBy, Species, NodeType, Family, Clade, NodeID, NodeName, ModelStatus, NodeDescription, AdditionalInfo, ExtDBlink, Process, ExternalDB, ModelV, GMM_OCD1, GMM_OCD, GMM_Description, GMM_ShortName, GMM_Synonyms, NodeLabel, observed_species, also_observed_in, chebi_identifier, pubmed_identifier]
# Index: []
#
# [0 rows x 24 columns]

# %%
qr = graph.run(q)
if not df_metabolites.shape[0] == qr.stats()['nodes_created']:
    raise Exception

# %%
df_metabolites[df_metabolites['Clade'] != df_metabolites['NodeID']]
# Out:
# Empty DataFrame
# Columns: [AddedBy, Species, NodeType, Family, Clade, NodeID, NodeName, ModelStatus, NodeDescription, AdditionalInfo, ExtDBlink, Process, ExternalDB, ModelV, GMM_OCD1, GMM_OCD, GMM_Description, GMM_ShortName, GMM_Synonyms, NodeLabel, observed_species, also_observed_in, chebi_identifier, pubmed_identifier]
# Index: []
#
# [0 rows x 24 columns]

# %%
label = "MetaboliteFamily"

# %%
df_metabolites
# Out:
#     AddedBy    Species    NodeType           Family            Clade  \
# 20       KG  plant_all  metabolite            L-Met            L-Met
# 21       KG  plant_all  metabolite             SAMe             SAMe
# 22       KG  plant_all  metabolite              ACC              ACC
# 23       KG  plant_all  metabolite               ET               ET
# 24       KG  plant_all  metabolite             Cu2+             Cu2+
# 165      KG  plant_all  metabolite          PUFA:LA          PUFA:LA
# 166      KG  plant_all  metabolite          13-HPOT          13-HPOT
# 167      KG  plant_all  metabolite        12,13-EOT        12,13-EOT
# 168      KG  plant_all  metabolite             OPDA             OPDA
# 169      KG  plant_all  metabolite             OPC8             OPC8
# 170      KG  plant_all  metabolite         OPC8-CoA         OPC8-CoA
# 171      KG  plant_all  metabolite         OPC6-CoA         OPC6-CoA
# 172      KG  plant_all  metabolite         OPC4-CoA         OPC4-CoA
# 173      KG  plant_all  metabolite           JA-CoA           JA-CoA
# 174      KG  plant_all  metabolite               JA               JA
# 175      KG  plant_all  metabolite             MeJA             MeJA
# 176      KG  plant_all  metabolite           JA-Ile           JA-Ile
# 177      KG  plant_all  metabolite     12-OH-JA-Ile     12-OH-JA-Ile
# 179      KG  plant_all  metabolite              Thr              Thr
# 180      KG  plant_all  metabolite              Ile              Ile
# 278      KG  plant_all  metabolite             Chor             Chor
# 279      KG  plant_all  metabolite          IsoChor          IsoChor
# 280      KG  plant_all  metabolite             Prep             Prep
# 281      KG  plant_all  metabolite           PhePyr           PhePyr
# 282      KG  plant_all  metabolite           PheAla           PheAla
# 283      KG  plant_all  metabolite          TransCA          TransCA
# 284      KG  plant_all  metabolite          OrthoCA          OrthoCA
# 285      KG  plant_all  metabolite               BA               BA
# 286      KG  plant_all  metabolite               SA               SA
# 287      KG  plant_all  metabolite             MeSA             MeSA
# ..      ...        ...         ...              ...              ...
# 936      AG        all  metabolite              ATP              ATP
# 937      AG        all  metabolite      UDP glucose      UDP glucose
# 938      AG        all  metabolite            NADPH            NADPH
# 939      AG        all  metabolite              DHZ               DZ
# 940      AG        all  metabolite             DHZR              DZR
# 941      AG        all  metabolite            DZRMP            DZRMP
# 942      AG        all  metabolite            tZRDP            tZRDP
# 943      AG        all  metabolite            tZRTP            tZRTP
# 944      AG        all  metabolite              cZR              cZR
# 945      AG        all  metabolite            cZRMP            cZRMP
# 946      AG        all  metabolite  cis-prenyl-tRNA  cis-prenyl-tRNA
# 947      AG        all  metabolite      prenyl-tRNA      prenyl-tRNA
# 948      AG        all  metabolite             tRNA             tRNA
# 949      AG        all  metabolite             iP7G             iP7G
# 950      AG        all  metabolite             iP9G             iP9G
# 951      AG        all  metabolite              Ade              Ade
# 952      AG        all  metabolite              Ado              Ado
# 953      AG        all  metabolite             tZOG             tZOG
# 954      AG        all  metabolite            tZROG            tZROG
# 955      AG        all  metabolite             tZ7G             tZ7G
# 956      AG        all  metabolite             tZ9G             tZ9G
# 957      AG        all  metabolite            DHZOG             DZOG
# 958      AG        all  metabolite           DHZROG            DZROG
# 959      AG        all  metabolite            DHZ7G             DZ7G
# 960      AG        all  metabolite            DHZ9G             DZ9G
# 961      AG        all  metabolite             cZOG             cZOG
# 962      AG        all  metabolite            cZROG            cZROG
# 963      AG        all  metabolite             cZ7G             cZ7G
# 964      AG        all  metabolite             cZ9G             cZ9G
# 965      AG        all  metabolite              Glu              Glu
#
#               NodeID         NodeName ModelStatus  \
# 20             L-Met            L-Met         use
# 21              SAMe             SAMe         use
# 22               ACC              ACC         use
# 23                ET               ET         use
# 24              Cu2+             Cu2+         use
# 165          PUFA:LA          PUFA:LA         use
# 166          13-HPOT          13-HPOT         use
# 167        12,13-EOT        12,13-EOT         use
# 168             OPDA             OPDA         use
# 169             OPC8             OPC8         use
# 170         OPC8-CoA         OPC8-CoA         use
# 171         OPC6-CoA         OPC6-CoA         use
# 172         OPC4-CoA         OPC4-CoA         use
# 173           JA-CoA           JA-CoA         use
# 174               JA               JA         use
# 175             MeJA             MeJA         use
# 176           JA-Ile           JA-Ile         use
# 177     12-OH-JA-Ile     12-OH-JA-Ile         use
# 179              Thr              Thr         use
# 180              Ile              Ile         use
# 278             Chor             Chor         use
# 279          IsoChor          IsoChor         use
# 280             Prep             Prep         use
# 281           PhePyr           PhePyr         use
# 282           PheAla           PheAla         use
# 283          TransCA          TransCA         use
# 284          OrthoCA          OrthoCA         use
# 285               BA               BA         use
# 286               SA               SA         use
# 287             MeSA             MeSA         use
# ..               ...              ...         ...
# 936              ATP              ATP         use
# 937      UDP glucose      UDP glucose         use
# 938            NADPH            NADPH         use
# 939               DZ               DZ         use
# 940              DZR              DZR         use
# 941            DZRMP            DZRMP         use
# 942            tZRDP            tZRDP         use
# 943            tZRTP            tZRTP         use
# 944              cZR              cZR         use
# 945            cZRMP            cZRMP         use
# 946  cis-prenyl-tRNA  cis-prenyl-tRNA         use
# 947      prenyl-tRNA      prenyl-tRNA         use
# 948             tRNA             tRNA         use
# 949             iP7G             iP7G         use
# 950             iP9G             iP9G         use
# 951              Ade              Ade         use
# 952              Ado              Ado         use
# 953             tZOG             tZOG         use
# 954            tZROG            tZROG         use
# 955             tZ7G             tZ7G         use
# 956             tZ9G             tZ9G         use
# 957             DZOG             DZOG         use
# 958            DZROG            DZROG         use
# 959             DZ7G             DZ7G         use
# 960             DZ9G             DZ9G         use
# 961             cZOG             cZOG         use
# 962            cZROG            cZROG         use
# 963             cZ7G             cZ7G         use
# 964             cZ9G             cZ9G         use
# 965              Glu              Glu         use
#
#                                        NodeDescription  \
# 20                                        L-methionine
# 21                             S-adenosyl-L-methionine
# 22                   1-aminocyclopropane-1-carboxylate
# 23                                            ethylene
# 24                                              copper
# 165         polyunsaturated fatty acids: linoleic acid
# 166       13-hydroperoxy-9,11,15-octadecatrienoic acid
# 167                       12,13(S)-epoxylinolenic acid
# 168          12-oxophytodienoic acid in the peroxisome
# 169             oxopentenyl-cyclopentane-octanoic acid
# 170              oxopentenyl-cyclopentane-octanoyl-CoA
# 171                                           OPC6-CoA
# 172                                           OPC4-CoA
# 173                                      jasmonoyl-CoA
# 174                                      jasmonic acid
# 175  methyl jasmonic acid: (-)-jasmonic acid methyl...
# 176  jasmonoyl-isoleucine: (+)-7-iso-jasmonoyl-L-is...
# 177      12-hydroxyjasmonic acid 12-O-beta-D-glucoside
# 179                               amino acid Threonine
# 180                              amino acid Isoleucine
# 278                                         chorismate
# 279                                      isochorismate
# 280                                         prephenate
# 281                                     phenylpyruvate
# 282                                      phenylalanine
# 283                                trans-cinnamic acid
# 284                                ortho-coumaric acid
# 285                                       benzoic acid
# 286                                         salicylate
# 287                                  methyl salicylate
# ..                                                 ...
# 936                          adenosine 5'-triphosphate
# 937                                      UDP-D-glucose
# 938        nicotinamide adenine dinucleotide phosphate
# 939                                      dihydrozeatin
# 940                             dihydrozeatin riboside
# 941               dihydrozeatin riboside monophosphate
# 942              9-ribosyl-trans-zeatin-5'-diphosphate
# 943             9-ribosyl-trans-zeatin-5'-triphosphate
# 944                               cis-zeatin riboside
# 945                 cis-zeatin riboside monophosphate
# 946  cis-prenyl-tRNA; N6-(cis-hydroxy)isopentenylad...
# 947     prenyl-tRNA; N6-dimethylallyladenosine in tRNA
# 948                                  adenosine in tRNA
# 949        7-(alpha-D-glucosyl)-N6-isopentenyladenine
# 950        9-(alpha-D-glucosyl)-N6-isopentenyladenine
# 951                                            adenine
# 952                                          adenosine
# 953                    O-beta-D-glucosyl-trans-zeatin
# 954                   O-glucosyl-trans-zeatin riboside
# 955                    trans-zeatin-7-beta-D-glucoside
# 956                  9-(alpha-D-glucosyl)-trans-zeatin
# 957                          dihydrozeatin-O-glucoside
# 958                 dihydrozeatin riboside-O-glucoside
# 959                 7-(alpha-D-glucosyl)dihydrozeatin
# 960                 9-(alpha-D-glucosyl)dihydrozeatin
# 961                      O-beta-D-glucosyl-cis-zeatin
# 962                     O-glucosyl-cis-zeatin riboside
# 963                    7-(beta-D-glucosyl)-cis-zeatin
# 964                    9-(beta-D-glucosyl)-cis-zeatin
# 965                                UDP-alpha-D-glucose
#
#                                         AdditionalInfo  ... GMM_OCD1 GMM_OCD  \
# 20                                                 NaN  ...      NaN     NaN
# 21                                                 NaN  ...      NaN     NaN
# 22                                                 NaN  ...      NaN     NaN
# 23                                                 NaN  ...      NaN     NaN
# 24                                                 NaN  ...      NaN     NaN
# 165  HA | polyunsaturated fatty acids: hexadecatrie...  ...      NaN     NaN
# 166  11-HPHT | 11(S)-hydroperoxy-hexadecatrienoic a...  ...      NaN     NaN
# 167                  10,11-EHT | parallel path to OPDA  ...      NaN     NaN
# 168         dnOPDA | dinorOPDA | parallel path to OPDA  ...      NaN     NaN
# 169                                                NaN  ...      NaN     NaN
# 170                                                NaN  ...      NaN     NaN
# 171                                                NaN  ...      NaN     NaN
# 172                                                NaN  ...      NaN     NaN
# 173                                                NaN  ...      NaN     NaN
# 174  (+)-7-iso-jasmonate (interconverted through sp...  ...      NaN     NaN
# 175                                                NaN  ...      NaN     NaN
# 176  (-)-jasmonoyl-L-isoleucine (the non-active for...  ...      NaN     NaN
# 177                                                NaN  ...      NaN     NaN
# 179                                                NaN  ...      NaN     NaN
# 180                                                NaN  ...      NaN     NaN
# 278                                                NaN  ...      NaN     NaN
# 279                                                NaN  ...      NaN     NaN
# 280                                                NaN  ...      NaN     NaN
# 281                                                NaN  ...      NaN     NaN
# 282                                                NaN  ...      NaN     NaN
# 283                                                NaN  ...      NaN     NaN
# 284                                                NaN  ...      NaN     NaN
# 285                                                NaN  ...      NaN     NaN
# 286                                                NaN  ...      NaN     NaN
# 287                                                NaN  ...      NaN     NaN
# ..                                                 ...  ...      ...     ...
# 936                                                NaN  ...      NaN     NaN
# 937                                                NaN  ...      NaN     NaN
# 938                                                NaN  ...      NaN     NaN
# 939                                                NaN  ...      NaN     NaN
# 940                                                NaN  ...      NaN     NaN
# 941                                                NaN  ...      NaN     NaN
# 942                                                NaN  ...      NaN     NaN
# 943                                                NaN  ...      NaN     NaN
# 944                                                NaN  ...      NaN     NaN
# 945                                                NaN  ...      NaN     NaN
# 946                                                NaN  ...      NaN     NaN
# 947                                                NaN  ...      NaN     NaN
# 948                                                NaN  ...      NaN     NaN
# 949                                                NaN  ...      NaN     NaN
# 950                                                NaN  ...      NaN     NaN
# 951                                                NaN  ...      NaN     NaN
# 952                                                NaN  ...      NaN     NaN
# 953                                                NaN  ...      NaN     NaN
# 954                                                NaN  ...      NaN     NaN
# 955                                                NaN  ...      NaN     NaN
# 956                                                NaN  ...      NaN     NaN
# 957                                                NaN  ...      NaN     NaN
# 958                                                NaN  ...      NaN     NaN
# 959                                                NaN  ...      NaN     NaN
# 960                                                NaN  ...      NaN     NaN
# 961                                                NaN  ...      NaN     NaN
# 962                                                NaN  ...      NaN     NaN
# 963                                                NaN  ...      NaN     NaN
# 964                                                NaN  ...      NaN     NaN
# 965                                                NaN  ...      NaN     NaN
#
#     GMM_Description GMM_ShortName GMM_Synonyms   NodeLabel observed_species  \
# 20              NaN           NaN          NaN  Metabolite        plant_all
# 21              NaN           NaN          NaN  Metabolite        plant_all
# 22              NaN           NaN          NaN  Metabolite        plant_all
# 23              NaN           NaN          NaN  Metabolite        plant_all
# 24              NaN           NaN          NaN  Metabolite        plant_all
# 165             NaN           NaN          NaN  Metabolite        plant_all
# 166             NaN           NaN          NaN  Metabolite        plant_all
# 167             NaN           NaN          NaN  Metabolite        plant_all
# 168             NaN           NaN          NaN  Metabolite        plant_all
# 169             NaN           NaN          NaN  Metabolite        plant_all
# 170             NaN           NaN          NaN  Metabolite        plant_all
# 171             NaN           NaN          NaN  Metabolite        plant_all
# 172             NaN           NaN          NaN  Metabolite        plant_all
# 173             NaN           NaN          NaN  Metabolite        plant_all
# 174             NaN           NaN          NaN  Metabolite        plant_all
# 175             NaN           NaN          NaN  Metabolite        plant_all
# 176             NaN           NaN          NaN  Metabolite        plant_all
# 177             NaN           NaN          NaN  Metabolite        plant_all
# 179             NaN           NaN          NaN  Metabolite        plant_all
# 180             NaN           NaN          NaN  Metabolite        plant_all
# 278             NaN           NaN          NaN  Metabolite        plant_all
# 279             NaN           NaN          NaN  Metabolite        plant_all
# 280             NaN           NaN          NaN  Metabolite        plant_all
# 281             NaN           NaN          NaN  Metabolite        plant_all
# 282             NaN           NaN          NaN  Metabolite        plant_all
# 283             NaN           NaN          NaN  Metabolite        plant_all
# 284             NaN           NaN          NaN  Metabolite        plant_all
# 285             NaN           NaN          NaN  Metabolite        plant_all
# 286             NaN           NaN          NaN  Metabolite        plant_all
# 287             NaN           NaN          NaN  Metabolite        plant_all
# ..              ...           ...          ...         ...              ...
# 936             NaN           NaN          NaN  Metabolite              all
# 937             NaN           NaN          NaN  Metabolite              all
# 938             NaN           NaN          NaN  Metabolite              all
# 939             NaN           NaN          NaN  Metabolite              all
# 940             NaN           NaN          NaN  Metabolite              all
# 941             NaN           NaN          NaN  Metabolite              all
# 942             NaN           NaN          NaN  Metabolite              all
# 943             NaN           NaN          NaN  Metabolite              all
# 944             NaN           NaN          NaN  Metabolite              all
# 945             NaN           NaN          NaN  Metabolite              all
# 946             NaN           NaN          NaN  Metabolite              all
# 947             NaN           NaN          NaN  Metabolite              all
# 948             NaN           NaN          NaN  Metabolite              all
# 949             NaN           NaN          NaN  Metabolite              all
# 950             NaN           NaN          NaN  Metabolite              all
# 951             NaN           NaN          NaN  Metabolite              all
# 952             NaN           NaN          NaN  Metabolite              all
# 953             NaN           NaN          NaN  Metabolite              all
# 954             NaN           NaN          NaN  Metabolite              all
# 955             NaN           NaN          NaN  Metabolite              all
# 956             NaN           NaN          NaN  Metabolite              all
# 957             NaN           NaN          NaN  Metabolite              all
# 958             NaN           NaN          NaN  Metabolite              all
# 959             NaN           NaN          NaN  Metabolite              all
# 960             NaN           NaN          NaN  Metabolite              all
# 961             NaN           NaN          NaN  Metabolite              all
# 962             NaN           NaN          NaN  Metabolite              all
# 963             NaN           NaN          NaN  Metabolite              all
# 964             NaN           NaN          NaN  Metabolite              all
# 965             NaN           NaN          NaN  Metabolite              all
#
#     also_observed_in chebi_identifier pubmed_identifier
# 20               NaN      CHEBI:16643               NaN
# 21               NaN      CHEBI:15414               NaN
# 22               NaN      CHEBI:30526               NaN
# 23               NaN      CHEBI:18153               NaN
# 24               NaN      CHEBI:29036               NaN
# 165              NaN      CHEBI:17351               NaN
# 166              NaN      CHEBI:48905               NaN
# 167              NaN      CHEBI:15653               NaN
# 168              NaN      CHEBI:34005               NaN
# 169              NaN              NaN  PubChem:25244083
# 170              NaN              NaN  PubChem:44237325
# 171              NaN              NaN  PubChem:44237133
# 172              NaN              NaN  PubChem:44237211
# 173              NaN              NaN  PubChem:44237154
# 174              NaN              NaN  PubChem:25245750
# 175              NaN              NaN   PubChem:5367719
# 176              NaN              NaN  PubChem:54758681
# 177              NaN      CHEBI:34005               NaN
# 179              NaN      CHEBI:57926               NaN
# 180              NaN      CHEBI:58045               NaN
# 278              NaN      CHEBI:29748               NaN
# 279              NaN      CHEBI:29780               NaN
# 280              NaN      CHEBI:57852               NaN
# 281              NaN      CHEBI:32815               NaN
# 282              NaN      CHEBI:28044               NaN
# 283              NaN      CHEBI:23252               NaN
# 284              NaN      CHEBI:23401               NaN
# 285              NaN      CHEBI:22723               NaN
# 286              NaN      CHEBI:16914               NaN
# 287              NaN      CHEBI:31832               NaN
# ..               ...              ...               ...
# 936              NaN              NaN               NaN
# 937              NaN              NaN               NaN
# 938              NaN              NaN               NaN
# 939              NaN              NaN               NaN
# 940              NaN              NaN               NaN
# 941              NaN              NaN               NaN
# 942              NaN              NaN               NaN
# 943              NaN              NaN               NaN
# 944              NaN              NaN               NaN
# 945              NaN              NaN               NaN
# 946              NaN              NaN               NaN
# 947              NaN              NaN               NaN
# 948              NaN              NaN               NaN
# 949              NaN              NaN               NaN
# 950              NaN              NaN               NaN
# 951              NaN              NaN               NaN
# 952              NaN              NaN               NaN
# 953              NaN              NaN               NaN
# 954              NaN              NaN               NaN
# 955              NaN              NaN               NaN
# 956              NaN              NaN               NaN
# 957              NaN              NaN               NaN
# 958              NaN              NaN               NaN
# 959              NaN              NaN               NaN
# 960              NaN              NaN               NaN
# 961              NaN              NaN               NaN
# 962              NaN              NaN               NaN
# 963              NaN              NaN               NaN
# 964              NaN              NaN               NaN
# 965              NaN              NaN               NaN
#
# [102 rows x 24 columns]

# %%
df_metabolites_has_family = df_metabolites[df_metabolites['Family'] != df_metabolites['NodeID']]

# %%
want_columns = ['AddedBy', 'Family',
        'NodeDescription',
       'AdditionalInfo', 'Process', 'ModelV']

# %%
df_metabolites_has_family[want_columns].drop_duplicates()
# Out:
#     AddedBy     Family                                 NodeDescription  \
# 523      MZ     PreROS                          ROS precursors; oxygen
# 524      MZ        ROS     hydrogen peroxide (reactive oxygen species)
# 525      MZ        ROS      superoxide anion (reactive oxygen species)
# 526      MZ        ROS      hydroxyl radical (reactive oxygen species)
# 527      MZ        ROS  hydroperoxyl radical (reactive oxygen species)
# 528      MZ        ROS                 ozone (reactive oxygen species)
# 529      MZ    PostROS                                           water
# 752      KG  DAMP/HAMP                             oligogalacturonides
# 933      AG      tZRMP         9-ribosyl-trans-zeatin-5'-monophosphate
# 939      AG        DHZ                                   dihydrozeatin
# 940      AG       DHZR                          dihydrozeatin riboside
# 957      AG      DHZOG                       dihydrozeatin-O-glucoside
# 958      AG     DHZROG              dihydrozeatin riboside-O-glucoside
# 959      AG      DHZ7G              7-(alpha-D-glucosyl)dihydrozeatin
# 960      AG      DHZ9G              9-(alpha-D-glucosyl)dihydrozeatin
#
#                                 AdditionalInfo     Process ModelV
# 523                                        NaN       S:ROS   v2.6
# 524                                        NaN       S:ROS   v2.6
# 525                                        NaN       S:ROS   v2.6
# 526                                        NaN       S:ROS   v1.0
# 527                                        NaN       S:ROS   v2.6
# 528                                        NaN       S:ROS   v2.6
# 529                                        NaN       S:ROS   v2.7
# 752  damage/host associated molecular patterns         NaN   v2.6
# 933                                        NaN  Hormone:CK    vNA
# 939                                        NaN  Hormone:CK    vNA
# 940                                        NaN  Hormone:CK    vNA
# 957                                        NaN  Hormone:CK    vNA
# 958                                        NaN  Hormone:CK    vNA
# 959                                        NaN  Hormone:CK    vNA
# 960                                        NaN  Hormone:CK    vNA

# %%
df_metabolites_family = df_metabolites_has_family.groupby('Family').agg({
                                                                  'Family':lambda x:list(x)[0],
                                                                  'AddedBy':lambda x:list(x)[0], 
                                                                  'NodeDescription':lambda x: ', '.join(x), 
                                                                  'AdditionalInfo':lambda x: helpers.list_to_string(x), 
                                                                  'Process':lambda x:list(x)[0], 
                                                                  'ModelV':helpers.get_latest_model})

# %%
df_metabolites_family
# Out:
#               Family AddedBy  \
# Family
# DAMP/HAMP  DAMP/HAMP      KG
# DHZ              DHZ      AG
# DHZ7G          DHZ7G      AG
# DHZ9G          DHZ9G      AG
# DHZOG          DHZOG      AG
# DHZR            DHZR      AG
# DHZROG        DHZROG      AG
# PostROS      PostROS      MZ
# PreROS        PreROS      MZ
# ROS              ROS      MZ
# tZRMP          tZRMP      AG
#
#                                              NodeDescription  \
# Family
# DAMP/HAMP                                oligogalacturonides
# DHZ                                            dihydrozeatin
# DHZ7G                     7-(alpha-D-glucosyl)dihydrozeatin
# DHZ9G                     9-(alpha-D-glucosyl)dihydrozeatin
# DHZOG                              dihydrozeatin-O-glucoside
# DHZR                                  dihydrozeatin riboside
# DHZROG                    dihydrozeatin riboside-O-glucoside
# PostROS                                                water
# PreROS                                ROS precursors; oxygen
# ROS        hydrogen peroxide (reactive oxygen species), s...
# tZRMP                9-ribosyl-trans-zeatin-5'-monophosphate
#
#                                       AdditionalInfo     Process ModelV
# Family
# DAMP/HAMP  damage/host associated molecular patterns         NaN   v2.6
# DHZ                                                   Hormone:CK   v0.0
# DHZ7G                                                 Hormone:CK   v0.0
# DHZ9G                                                 Hormone:CK   v0.0
# DHZOG                                                 Hormone:CK   v0.0
# DHZR                                                  Hormone:CK   v0.0
# DHZROG                                                Hormone:CK   v0.0
# PostROS                                                    S:ROS   v2.7
# PreROS                                                     S:ROS   v2.6
# ROS                                                        S:ROS   v2.6
# tZRMP                                                 Hormone:CK   v0.0

# %%
f = '%s-components.tsv'%label
df_metabolites_family.to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.component_node_query(f, label, 
                     n_name="line.Family"
                    )

# %%
qr = graph.run(q)
if not df_metabolites_family.shape[0] == qr.stats()['nodes_created']:
    raise Exception

# %%
# Metabolite to MetaboliteFamily edges
want_columns = ['AddedBy', 'Family', 'NodeName', 'ModelV']
edge_type = 'TYPE_OF'
f = '%s-edges.tsv'%edge_type
df_metabolites_has_family[want_columns].to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.make_create_edge_query(f, edge_type, 
                           source_label="Metabolite", target_label="MetaboliteFamily",
                           source_name="line.NodeName", target_name="line.Family")

# %%
qr = graph.run(q)
if not df_metabolites_has_family.shape[0] == qr.stats()['relationships_created']:
    raise Exception

# %% [markdown]
# ## Pathogens (External)

# %%
df_external = df_components[df_components["NodeLabel"].isin(["ExternalCoding", "ExternalNonCoding"])].copy()

# %%
df_external.columns = ['AddedBy', 'O-Species', 'NodeType', 'classification', 'species',
       'NodeID', 'NodeName', 'ModelStatus', 'NodeDescription',
       'AdditionalInfo', 'ExtDBlink', 'Process', 'ExternalDB', 'ModelV',
       'GMM_OCD1', 'GMM_OCD', 'GMM_Description', 'GMM_ShortName',
       'GMM_Synonyms', 'NodeLabel', 'observed_species',
       'also_observed_in', 'chebi_identifier', 'pubmed_identifier']

# %%
want_columns = ['AddedBy',
       'NodeID', 'NodeName', 'NodeDescription',
       'AdditionalInfo', 'Process', 'ExternalDB', 'ModelV',
       'GMM_OCD1', 'GMM_OCD', 'GMM_Description', 'GMM_ShortName',
       'GMM_Synonyms', 'chebi_identifier', 'pubmed_identifier']

# %%
df_external[['O-Species', 'NodeType', 'classification', 'species', 'NodeID', 'NodeName', 'observed_species']]
# Out:
#     O-Species         NodeType classification            species    NodeID  \
# 451  external  pathogen_coding          virus          potyvirus       6K1
# 452  external  pathogen_coding          virus          potyvirus       6K2
# 453  external  pathogen_coding          virus          potyvirus        CI
# 454  external  pathogen_coding          virus          potyvirus        CP
# 455  external  pathogen_coding          virus          potyvirus    HC-Pro
# 456  external  pathogen_coding          virus          potyvirus   NIa-Pro
# 457  external  pathogen_coding          virus          potyvirus       NIb
# 458  external  pathogen_coding          virus          potyvirus        P1
# 459  external  pathogen_coding          virus          potyvirus        P3
# 460  external  pathogen_coding          virus          potyvirus  P3N-PIPO
# 461  external  pathogen_coding          virus          potyvirus       VPg
# 462  external  pathogen_coding       bacteria  trichous-bacteria     flg22
# 463  external  pathogen_coding       bacteria  trichous-bacteria     elf18
# 464  external  pathogen_coding          fungi           oomycete        ch
#
#      NodeName observed_species
# 451       6K1         external
# 452       6K2         external
# 453        CI         external
# 454        CP         external
# 455    HC-Pro         external
# 456   NIa-Pro         external
# 457       NIb         external
# 458        P1         external
# 459        P3         external
# 460  P3N-PIPO         external
# 461       VPg         external
# 462     flg22         external
# 463     elf18         external
# 464        ch         external

# %%
for label, subdf in df_external.groupby('NodeLabel'):
    print(label, end='\t')
    f = '%s-components.tsv'%label
    subdf[want_columns].to_csv("../data/import/" + f, sep="\t", index=None)
    
    q = helpers.component_node_query(f, label, 
                     n_name="line.NodeName"
                    )
    
    qr = graph.run(q)
    if not subdf.shape[0] == qr.stats()['nodes_created']:
        raise Exception
# Out:
# ExternalCoding

# %%
external_organisms = df_external.groupby('species').agg({
                                                      'classification':lambda x:list(x)[0],
                                                      'AddedBy':lambda x:list(x)[0], 
                                                      #'NodeDescription':lambda x: ', '.join(x), 
                                                      #'AdditionalInfo':lambda x: ', '.join(x), 
                                                      #'Process':lambda x:list(x)[0], 
                                                      'ModelV':helpers.get_latest_model}).reset_index()

# %%
external_organisms
# Out:
#              species classification AddedBy ModelV
# 0           oomycete          fungi      KG   v0.0
# 1          potyvirus          virus      KG   v2.6
# 2  trichous-bacteria       bacteria      KG

# %%
label = 'ExternalOrganism'
f = '%s-components.tsv'%label
external_organisms.to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.component_node_query(f, label, 
                     n_name="line.species", 
                    )

# %%
qr = graph.run(q)
if not external_organisms.shape[0] == qr.stats()['nodes_created']:
    raise Exception

# %%
# External to ExternalOrganism edges
want_columns = ['NodeName', 'species', 'ModelV']
edge_type = 'AGENT_OF'
f = '%s-edges.tsv'%edge_type
df_external[want_columns].to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.make_create_edge_query(f, edge_type, 
                           source_label="", target_label="ExternalOrganism",
                           source_name="line.NodeName", target_name="line.species")

# %%
qr = graph.run(q)
if not df_external.shape[0] == qr.stats()['relationships_created']:
    raise Exception

# %% [markdown]
# ## Bio-elements

# %%
df_bioelements = df_components[df_components['NodeLabel'].isin(['PlantCoding', 
                                                                 'PlantNonCoding',
                                                                 'PlantAbstract', 
                                                                 'Complex'
                                                                ])].copy()

# %%
df_bioelements['Species'].unique()
# Out:
# array(['ath', 'plant_all', 'stu', 'osa'], dtype=object)

# %%
pd.value_counts(df_bioelements['NodeLabel'])
# Out:
# PlantCoding       825
# PlantAbstract      12
# PlantNonCoding     12
# Complex             1
# Name: NodeLabel, dtype: int64

# %%
all_species_listed = list(df_bioelements['Species'].unique()); all_species_listed
# Out:
# ['ath', 'plant_all', 'stu', 'osa']

# %%
all_species = all_species_listed.copy()

# %%
all_species.remove('plant_all')
all_species.remove('all')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-d3eecc67a504> in <module>
#       1 all_species.remove('plant_all')
# ----> 2 all_species.remove('all')
#
# ValueError: list.remove(x): x not in list

# %%
all_species
# Out:
# ['ath', 'stu', 'osa']

# %%
def pick_the_set(x):
    for v in x:
        if type(v) == set:
            return v
    return {}


def get_species_homologues(level):
    df_level_species  = df_bioelements.groupby([level, 'Species']).agg({
      'NodeID':lambda x: set(x), 
    })
    df_level_species.reset_index(1, inplace=True)

    cols = []
    for specie in all_species:
        col = specie + '_homologues'
        cols.append(col)
        df_level_species.loc[df_level_species['Species'] == specie, col] =\
         df_level_species[df_level_species['Species'] == specie]['NodeID']
    
    df_level_species = df_level_species[cols].groupby(level).agg({
        y:pick_the_set for y in cols
    })
    
    df_level = df_bioelements.groupby(level).agg({
          'AddedBy':lambda x:list(x)[0], 
          'NodeLabel':lambda x:list(x)[0], 
          'NodeDescription':lambda x: ', '.join(list(set(x))), 
          'AdditionalInfo':lambda x: helpers.list_to_string(x), 
          'Process':lambda x:list(x)[0], 
          'ModelV':helpers.get_latest_model, 
          'Species':lambda x: set(x), 
    })    

    df_level = df_level.join(df_level_species[cols])
    df_level.reset_index(inplace=True)
    
    return df_level

# %%
df_families = get_species_homologues("Family")

# %%
# save node types 
family_node_labels = []
for t, subdf in df_families.groupby("NodeLabel"):
    print(t, "\t", subdf.shape[0])
    subdf.to_csv("../data/import/%s-components.tsv"%t, sep="\t", index=None)
    family_node_labels.append(t)
# Out:
# Complex 	 1
# PlantAbstract 	 7
# PlantCoding 	 161
# PlantNonCoding 	 9

# %%
for t in family_node_labels:
    query = helpers.component_node_query("%s-components.tsv"%t, n_name="line.Family", labels=[t, 'Family'])
    #query = f"MATCH (n:{t}) DELETE n"
    qr = graph.run(query)
    print(t, "\t", qr.stats()['nodes_created'])
# Out:
# Complex 	 1
# PlantAbstract 	 7
# PlantCoding 	 161
# PlantNonCoding 	 9

# %%
file_name = os.path.join(input_path, "bio_elements.tsv")
df_bioelements.to_csv(file_name, sep="\t", index=False)

# %% [markdown]
# ## Process

# %%
df_process = df_components[df_components['NodeLabel'].isin(['Process'
                                                                ])].copy()

# %%
want_columns = ['AddedBy',
       'NodeName', 'NodeDescription', 'Process', 
       'AdditionalInfo', 'Process', 'ExternalDB', 'ModelV',
       'GMM_OCD1', 'GMM_OCD', 'GMM_Description', 'GMM_ShortName',
       'GMM_Synonyms', 'chebi_identifier', 'pubmed_identifier', 'observed_species']

# %%
label = "Process"
f = "%s-components.tsv"%label
df_process[want_columns].to_csv("../data/import/" + f, sep="\t", index=None)

# %%
q = helpers.component_node_query(f, label, 
                     n_name="line.NodeName", 
                    )

# %%
qr = graph.run(q)
if not df_process.shape[0] == qr.stats()['nodes_created']:
    raise Exception

# %%
qr.stats()
# Out:
# constraints_added: 0
# constraints_removed: 0
# contains_updates: True
# indexes_added: 0
# indexes_removed: 0
# labels_added: 6
# labels_removed: 0
# nodes_created: 6
# nodes_deleted: 0
# properties_set: 29
# relationships_created: 0
# relationships_deleted: 0

# %% [markdown]
# # END

# %% [markdown]
# ## Protein, Clade, Family keys

# %%
input_path
# Out:
# '../data/raw'

# %%
file_name = os.path.join(input_path, "bio_elements.tsv")
df_bioelements.to_csv(file_name, sep="\t", index=False)

# %%
id_to_name = df_bioelements[['NodeID', 'NodeName']]

# %%
id_to_name[id_to_name['NodeName'].duplicated()]['NodeName'].unique()
# Out:
# array(['CPS', 'GA20ox3', 'GA20ox1', 'GA20ox4', 'MYB33'], dtype=object)

# %%
df_nodes = get_species_homologues('NodeName')
df_nodes.set_index('NodeName', inplace=True)

# %%
# node name to node IDs
node_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    node_ids_key[col] = df_nodes[col].to_dict()

# %%
df_clades = get_species_homologues('Clade')
df_clades.set_index('Clade', inplace=True)

# %%
# clade name to node IDs
clade_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    clade_ids_key[col] = df_clades[col].to_dict()

# %%
# family name to node IDs
df_families.set_index("Family", inplace=True)
family_ids_key = {}
for species in all_species:
    col = species + '_homologues'
    family_ids_key[col] = df_families[col].to_dict()

# %%
node_to_family = df_bioelements[["NodeName", "Family"]].set_index("NodeName")["Family"].to_dict()

# %%
clade_to_family = df_bioelements[["Clade", "Family"]].set_index("Clade")["Family"].to_dict()

# %%
df_process['NodeName']
# Out:
# 780    Anthocyanin-accumulation
# 781         Trichome-initiation
# 782               RNA-silencing
# 783              ROS-production
# 784              AUX-signalling
# 785              CO2-deficiency
# Name: NodeName, dtype: object

# %%
df_components["Process"].unique()
# Out:
# array(['Hormone:ET', 'Hormone:JA', 'Hormone:SA', 'Hormone:AUX',
#        'Hormone:BS', 'Hormone:GA', 'S:Ca', 'P:Stress_HSPs', 'S:MAPKs',
#        'Pathogen', 'Pathogen_Effector', 'S:ROS', 'S:TFs',
#        'P:Primary-metabolism_Photosynthesis',
#        'P:Primary-metabolism_Respiration',
#        'P:Secondary-metabolism_Anthocyanins',
#        'P:Secondary-metabolism_Isoprenoids',
#        'P:Secondary-metabolism_Terpenoids', 'P:Ubiquitination',
#        'P:Silencing', 'P:Translation', nan, 'S:Rgenes', 'Hormone:CK',
#        'Hormone:SLs'], dtype=object)

# %% [markdown]
# ## Components summary

# %%
q = '''MATCH (n) RETURN DISTINCT n.name AS name, n.level AS level'''
nodes = graph.run(q).data()
all_nodes_in_components = set([(d["name"], d["level"]) for d in nodes])

# %%
len(all_nodes_in_components)
# Out:
# 313

# %%
sorted(df_components['NodeLabel'].unique())
# Out:
# ['Complex',
#  'ExternalCoding',
#  'Metabolite',
#  'PlantAbstract',
#  'PlantCoding',
#  'PlantNonCoding',
#  'Process',
#  'Undefined']

# %%
node_dict = {}
for label in node_labels:
    q = '''MATCH (n:%s) RETURN DISTINCT n.name'''%label
    s = set([d['n.name'] for d in graph.run(q).data()])
    print(label, len(s))
    node_dict[label] = s
# Out:
# PlantCoding 142
# PlantNonCoding 9
# PlantAbstract 7
# Complex 1
# ExternalOrganism 3
# ExternalCoding 14
# ExternalNonCoding 0
# Process 6
# MetaboliteFamily 4
# Metabolite 59

# %% [markdown]
# ### Reactions sheet

# %%
df_edges_orig = pd.read_excel(input_path, 
                         sheet_name="Reactions", 
                         header=[1], 
                         dtype=str, 
                         na_values=helpers.empty_strings)
df_edges_orig = df_edges_orig[df_edges_orig['Status'].isin(["forCB", "forCB_INVENTED"])]
df_edges_orig.drop(['Status', 'FOXMES', 'Legacy:Process', 'Legacy:ReactionMode'], axis=1, inplace=True)
df_edges_orig.columns = pd.Index(['AddedBy', 'ConnID', 'Species', 
          'input1_ID', 'input1_level', 'input1_localisation', 'input1_type', 
          'input2_ID', 'input2_level', 'input2_localisation', 'input2_type', 
          'input3_ID', 'input3_level', 'input3_localisation', 'input3_type', 
          'ReactionEffect', 'ReactionMode', 'Modifications',
          'output1_ID', 'output1_level', 'output1_localisation', 'output1_type', 
          'TrustLevel', 'Literature', 'AdditionalInfo', 'Comment', 'ModelV', 'kinetics'],
      dtype='object')

df_edges_new = pd.read_excel(input_path, 
                         sheet_name="Reactions_New", 
                         header=[1], 
                         dtype=str, 
                         na_values=helpers.empty_strings)
df_edges_new = df_edges_new[~df_edges_new['AddedBy'].isin(['-'])]
df_edges_new.drop(['Status'], axis=1, inplace=True)
df_edges_new.columns = pd.Index(['AddedBy', 'ConnID', 'Species', 
          'input1_ID', 'input1_level', 'input1_type', 
          'input2_ID', 'input2_level', 'input2_type', 
          'input3_ID', 'input3_level', 'input3_type',                                  
          'ReactionEffect', 'ReactionMode', 
          'output1_ID', 'output1_level', 'output1_type', 
          'TrustLevel', 'Literature', 'AdditionalInfo', 'Comment', 'ModelV'],
      dtype='object')


df_edges = pd.concat([df_edges_orig, df_edges_new], sort=False)

# %%
df_edges = df_edges[~df_edges["AddedBy"].isna()]

# %%
df_edges.tail()
# Out:
#      AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 46        sb  Conn310     ath       CAT       family                 NaN
# 47        sb  Conn310     ath        SA         node                 NaN
# 48        sb  Conn310     ath      CAT2         node                 NaN
# 49        sb  Conn310     ath      CAT2         node                 NaN
# 1737       x        x       x         x            x                 NaN
#
#        input1_type input2_ID input2_level input2_localisation  ... output1_ID  \
# 46    plant_coding      LSD1         node                 NaN  ...        NaN
# 47      metabolite      CAT2         node                 NaN  ...        NaN
# 48    plant_coding      ACX2         node                 NaN  ...        NaN
# 49    plant_coding      ACX3         node                 NaN  ...        NaN
# 1737             x       NaN            x                 NaN  ...          x
#
#      output1_level output1_localisation output1_type  \
# 46             NaN                  NaN          NaN
# 47             NaN                  NaN          NaN
# 48             NaN                  NaN          NaN
# 49             NaN                  NaN          NaN
# 1737             x                  NaN            x
#
#                                        TrustLevel  \
# 46    [R1] targetted experiments (e.g. Y2H, BIFC)
# 47                         [R4] indirect reaction
# 48    [R1] targetted experiments (e.g. Y2H, BIFC)
# 49    [R1] targetted experiments (e.g. Y2H, BIFC)
# 1737                                            x
#
#                           Literature  \
# 46         DOI:10.1104/pp.113.225805
# 47    DOI:10.1016/j.chom.2017.01.007
# 48    DOI:10.1016/j.chom.2017.01.007
# 49    DOI:10.1016/j.chom.2017.01.007
# 1737                               x
#
#                                          AdditionalInfo Comment ModelV  \
# 46    LSD1 interacted with all three catalases both ...     NaN    vNA
# 47    SA decreased CAT2 activity in a dose-dependent...     NaN    vNA
# 48    CAT2 Promotes the Activityof ACX2/ACX3 ( (test...     NaN    vNA
# 49    CAT2 Promotes the Activityof ACX2/ACX3 ( (test...     NaN    vNA
# 1737                                                  x       x      x
#
#      kinetics
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 1737      NaN
#
# [5 rows x 28 columns]

# %%
x = df_edges[df_edges['AddedBy']=='x'].index
print(x)
df_edges.drop(x, inplace=True)
# Out:
# Int64Index([1737], dtype='int64')

# %%
df_edges["TrustLevel"].unique()
# Out:
# array(['[R1] targetted experiments (e.g. Y2H, BIFC)',
#        '[Ry] invented reaction', '[Rx] incomplete/unspecific reaction',
#        '[R2] high-throughput experiment (e.g. ChIP-seq)',
#        '[R3] in-silico prediction', '[R4] indirect reaction'],
#       dtype=object)

# %%
df_edges['trust_level']  = df_edges["TrustLevel"].apply(lambda x: re.search( r"(R[1|2|3|4|x|y]|undefined)", x).groups()[0])
df_edges['observed_species'] = df_edges["Species"].apply(helpers.get_second_item)
df_edges['also_observed_in'] = df_edges["Species"].apply(helpers.rest_of_items)
df_edges['Comment'] = df_edges['Comment'].fillna("")
df_edges['AdditionalInfo'] = df_edges['AdditionalInfo'].fillna("")

# %%
df_edges['AddedBy'] = df_edges['AddedBy'].apply(lambda x: x.upper())
df_edges["AddedBy"].unique()
# Out:
# array(['KG', 'MZ', 'ZR', 'MPE', 'ACR', 'MAK', 'ŠT', 'SB'], dtype=object)

# %%
df_edges.loc[df_edges['ModelV'].isna(), 'ModelV'] = 'vNA'
df_edges['ModelV'].unique()
# Out:
# array(['v1.0', 'v2.5', 'v2.7', 'v2.6', 'vNA'], dtype=object)

# %%
def only_asci(x):
    return "".join([character for character in x if character.isascii()])

def doi_list(x):
    x = only_asci(x.lower())
    match = re.findall("(?:doi)(?:\:|\/)\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["doi:" + m.rstrip('.') for m in match]
    else:
        return []

def pubmed_list(x):
    x = only_asci(x.lower())
    match = re.findall("(?:pmid)\:\s*(.+?)(?:\s|$)", x)
    if not match is None:
        return ["pmid:" + m.rstrip('.') for m in match]
    else:
        return []

def list_to_string(x):
    return ",".join([str(i) for i in x])

# %%
# format literature sources
df_edges["Literature"].fillna(value="", inplace=True)
for i, row in df_edges.iterrows():
    s = row['Literature']
    source = doi_list(s)
    source += pubmed_list(s)
    for z in s.split("|"):
        key = z.lower()
        if ":" in key:
            if "aracyc" in key:
                aracyc_string = "aracyc:" + z.split(":")[1].strip()
                source.append(aracyc_string)
            elif "kegg" in key:
                kegg_string = "kegg:" + z.split(":")[1].strip()
                source.append(kegg_string)
            elif "doi" in key:
                # already fetched
                continue
            elif ("pubmed" in key) or ("pmid" in key):
                pmid_string = "pubmed:" + z.split(":")[1].strip()
        elif "invented" in key:
            source.append("invented")
        else:
            print("no/bad reference", row["ConnID"], z)
            source.append("other:" + only_asci(z.strip()))
    if len(source) > 0:
        df_edges.loc[i, "literature_sources"] = list_to_string(source)
    else:
        print(row["ConnID"], z)
# Out:
# no/bad reference Conn040
# no/bad reference Conn118
# no/bad reference Conn120
# no/bad reference Conn122
# no/bad reference Conn182
# no/bad reference Conn183
# no/bad reference Conn199 ? Kg need to find reference
# no/bad reference Conn273 KEGG
# no/bad reference Conn274 KEGG
# no/bad reference Conn275 KEGG
# no/bad reference Conn276 KEGG
# no/bad reference Conn276  10.1073/pnas.98.4.2065
# no/bad reference Conn277 KEGG
# no/bad reference Conn278 KEGG
# no/bad reference Conn279 KEGG
# no/bad reference Conn280 KEGG
# no/bad reference Conn281 KEGG
# no/bad reference Conn282 KEGG
# no/bad reference Conn283 KEGG
# no/bad reference Conn309

# %%
df_edges[["ConnID", "Literature", "literature_sources"]].to_csv("lit-check.tsv", sep="\t", index=None)

# %%
df_edges.reset_index(inplace=True, drop=True)

# %%
save_df = df_edges.copy()
#df_edges = save_df.copy()

# %%
df_edges[df_edges['ConnID'].duplicated()]
# Out:
#     AddedBy   ConnID Species            input1_ID      input1_level  \
# 74       KG  Conn080     ath  Trichome-initiation            family
# 260     MAK      NaN     ath            GID1a,b,c  clade/orthologue
# 261     MAK      NaN     ath            GID1a,b,c  clade/orthologue
# 268     MAK      NaN     ath             GA1-GID1            family
# 269     MAK      NaN     ath             GA3-GID1            family
# 270     MAK      NaN     ath             GA4-GID1            family
# 271     MAK      NaN     ath                 SLY1              node
# 272     MAK      NaN     osa                 GID2              node
# 273     MAK      NaN     ath       GA1-GID1-DELLA            family
# 274     MAK      NaN     osa        GA1-GID1-SLR1            family
# 287      SB  Conn310     ath                   SA              node
# 288      SB  Conn310     ath                 CAT2              node
# 289      SB  Conn310     ath                 CAT2              node
#
#     input1_localisation    input1_type  input2_ID input2_level  \
# 74                  NaN        process  potyvirus       family
# 260                 NaN   plant_coding        GA3       family
# 261                 NaN   plant_coding        GA4       family
# 268                 NaN  plant_complex      DELLA       family
# 269                 NaN  plant_complex      DELLA       family
# 270                 NaN  plant_complex      DELLA       family
# 271                 NaN   plant_coding        SCF       family
# 272                 NaN   plant_coding        SCF       family
# 273                 NaN  plant_complex   SCF-SLY1       family
# 274                 NaN  plant_complex   SCF-GID2       family
# 287                 NaN     metabolite       CAT2         node
# 288                 NaN   plant_coding       ACX2         node
# 289                 NaN   plant_coding       ACX3         node
#
#     input2_localisation  ...                                   TrustLevel  \
# 74                  NaN  ...                       [Ry] invented reaction
# 260                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 261                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 268                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 269                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 270                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 271                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 272                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 273                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 274                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 287                 NaN  ...                       [R4] indirect reaction
# 288                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
# 289                 NaN  ...  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                             Literature  \
# 74   DOI:10.1105/tpc.111.083261 (Qi, 2011: The jasm...
# 260                         DOI:10.1105/tpc.106.047415
# 261                         DOI:10.1105/tpc.106.047415
# 268                          DOI:10.1104/pp.112.200956
# 269                          DOI:10.1104/pp.112.200956
# 270                          DOI:10.1104/pp.112.200956
# 271                             DOI:10.1105/tpc.010827
# 272                        DOI:10.1126/science.1081077
# 273  DOI:10.1104/pp.112.200956 | DOI:10.1105/tpc.01...
# 274  DOI:10.1104/pp.112.200956 | https://doi.org/10...
# 287                     DOI:10.1016/j.chom.2017.01.007
# 288                     DOI:10.1016/j.chom.2017.01.007
# 289                     DOI:10.1016/j.chom.2017.01.007
#
#                                         AdditionalInfo Comment ModelV  \
# 74                                                               v2.7
# 260                                                               vNA
# 261                                                               vNA
# 268                                                               vNA
# 269                                                               vNA
# 270                                                               vNA
# 271                                                               vNA
# 272                                                               vNA
# 273                                                               vNA
# 274                                                               vNA
# 287  SA decreased CAT2 activity in a dose-dependent...            vNA
# 288  CAT2 Promotes the Activityof ACX2/ACX3 ( (test...            vNA
# 289  CAT2 Promotes the Activityof ACX2/ACX3 ( (test...            vNA
#
#     kinetics trust_level observed_species also_observed_in  \
# 74       NaN          Ry              ath
# 260      NaN          R1              ath
# 261      NaN          R1              ath
# 268      NaN          R1              ath
# 269      NaN          R1              ath
# 270      NaN          R1              ath
# 271      NaN          R1              ath
# 272      NaN          R1              osa
# 273      NaN          R1              ath
# 274      NaN          R1              osa
# 287      NaN          R4              ath
# 288      NaN          R1              ath
# 289      NaN          R1              ath
#
#                                    literature_sources
# 74                         doi:10.1105/tpc.111.083261
# 260                        doi:10.1105/tpc.106.047415
# 261                        doi:10.1105/tpc.106.047415
# 268                         doi:10.1104/pp.112.200956
# 269                         doi:10.1104/pp.112.200956
# 270                         doi:10.1104/pp.112.200956
# 271                            doi:10.1105/tpc.010827
# 272                       doi:10.1126/science.1081077
# 273  doi:10.1104/pp.112.200956,doi:10.1105/tpc.010827
# 274                         doi:10.1104/pp.112.200956
# 287                    doi:10.1016/j.chom.2017.01.007
# 288                    doi:10.1016/j.chom.2017.01.007
# 289                    doi:10.1016/j.chom.2017.01.007
#
# [13 rows x 32 columns]

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.           v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.           v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.           v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...           v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...           v1.0      NaN
#
#   trust_level observed_species also_observed_in  \
# 0          R1              ath
# 1          R1              ath
# 2          R1              ath
# 3          R1              ath
# 4          R1              ath
#
#                                   literature_sources
# 0                  doi:10.1042/bj20120245,other:KEGG
# 1                  doi:10.1042/bj20120245,other:KEGG
# 2                  doi:10.1042/bj20120245,other:KEGG
# 3  doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                  doi:10.1042/bj20120245,other:KEGG
#
# [5 rows x 32 columns]

# %%
for x in ['input1', 'input2', 'input3', 'output1']:
    df_edges.loc[:, x + "_ID"] = df_edges[x + "_ID"].apply(helpers.reorder_ids)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#                                     TrustLevel  \
# 0  [R1] targetted experiments (e.g. Y2H, BIFC)
# 1  [R1] targetted experiments (e.g. Y2H, BIFC)
# 2  [R1] targetted experiments (e.g. Y2H, BIFC)
# 3  [R1] targetted experiments (e.g. Y2H, BIFC)
# 4  [R1] targetted experiments (e.g. Y2H, BIFC)
#
#                                           Literature  \
# 0                                   AraCyc:ETHYL-PWY
# 1                                   AraCyc:ETHYL-PWY
# 2                                   AraCyc:ETHYL-PWY
# 3  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
# 4  DOI:10.1105/tpc.001768 (Ethylene Biosynthesis ...
#
#                                       AdditionalInfo Comment ModelV kinetics  \
# 0              SAMS catalyse L-Met to SAMe reaction.           v1.0      NaN
# 1                 ACS catalyse ACC to SAMe reaction.           v1.0      NaN
# 2                   ACO catalyse ACC to ET reaction.           v1.0      NaN
# 3  Copper gets transported from the cytoplasm to ...           v1.0      NaN
# 4  Copper activates the membrane bound ethylene r...           v1.0      NaN
#
#   trust_level observed_species also_observed_in  \
# 0          R1              ath
# 1          R1              ath
# 2          R1              ath
# 3          R1              ath
# 4          R1              ath
#
#                                   literature_sources
# 0                  doi:10.1042/bj20120245,other:KEGG
# 1                  doi:10.1042/bj20120245,other:KEGG
# 2                  doi:10.1042/bj20120245,other:KEGG
# 3  doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                  doi:10.1042/bj20120245,other:KEGG
#
# [5 rows x 32 columns]

# %%
def convert_node_to_family(x):
    # pathogen proteins are listed as proteins, so cannot use dict
    id_, type_, level_ = x.values
      
    if id_ is np.nan:
        return np.nan, np.nan

    new_label = None
    family_id = None
    
    ########################
    # Simple Cases
    ########################
    if type_ in ['complex', 'complex [active]', 'complex [activated]', 'complex [inactive]', 'plant_complex']:
        if not (id_ in node_dict["Complex"]):
            complexes_to_add.append(id_)
        new_label = 'Complex'
        family_id = id_
    
    elif type_ in ["metabolite"]:
        for label in ["Metabolite", "MetaboliteFamily"]:
            if id_ in node_dict[label]:
                new_label = label
                break
        if not new_label:
            missing_in_components.update([id_])        
            print(id_, type_, level_, " | (label) not a listed metabolite")
        family_id = id_

    elif type_ in ['process']:
        if (id_ in node_dict["Process"]):
            family_id = id_
            new_label = "Process"
        else:
            print(id_, type_, level_, " | (label) process not a listed process")
        
    else:
        ########################
        # family ID
        ########################
        check_external = False
        if level_ == "family":    
            family_id = id_
        elif level_ in ["clade", "clade/orthologue"]:
            try:
                family_id = clade_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        elif level_ == "node":
            try:
                family_id = node_to_family[id_]
                replace_w_family.update([id_])
            except KeyError:
                check_external = True
        
        if check_external:
            for label in ["ExternalOrganism", "ExternalCoding", "ExternalNonCoding"]:
                if id_ in node_dict[label]:
                    new_label = label
                    family_id = id_
                    break
                    
        if not family_id:
            print(id_, type_, level_, " | (family id) could not convert to family/external")
                
        ########################
        # Label
        ########################
        if (family_id) and (not new_label):
            id_labels = [] #looping just in case an id occurs mutiple times
            for label in node_labels:
                if family_id in node_dict[label]:
                    id_labels.append(label)

            if len(id_labels) == 1:
                new_label = id_labels[0]
            elif len(id_labels) > 1:
                print(id_, type_, level_, " | (label) many labels fit")
                missing_in_components.update([id_])       

            else:
                print(id_, type_, level_, " | (label) could not find label")
                missing_in_components.update([id_])        

    return family_id, new_label

# %%
complexes_to_add = []
missing_in_components = set()
replace_w_family = set()

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, level_col, new_id, new_label_col  =\
            [prefix + x for x in ('_ID',  '_type',  '_level',  '_newID', '_label')]    
    
    df_edges[[new_id, new_label_col]] = df_edges[[id_col, type_col, level_col]].apply(convert_node_to_family, axis=1, result_type='expand')
# Out:
# miR6022 plant_ncRNA node  | (family id) could not convert to family/external
# LSD1 plant_coding node  | (family id) could not convert to family/external

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   also_observed_in                                 literature_sources  \
# 0                                   doi:10.1042/bj20120245,other:KEGG
# 1                                   doi:10.1042/bj20120245,other:KEGG
# 2                                   doi:10.1042/bj20120245,other:KEGG
# 3                   doi:10.1042/bj20120245,other:KEGG,other:10.107...
# 4                                   doi:10.1042/bj20120245,other:KEGG
#
#   input1_newID input1_label input2_newID input2_label input3_newID  \
# 0        L-Met   Metabolite          SAM  PlantCoding          NaN
# 1         SAMe   Metabolite          ACS  PlantCoding          NaN
# 2          ACC   Metabolite          ACO  PlantCoding          NaN
# 3         Cu2+   Metabolite          HMA  PlantCoding          NaN
# 4          ETR  PlantCoding         Cu2+   Metabolite          NaN
#
#   input3_label output1_newID output1_label
# 0          NaN          SAMe    Metabolite
# 1          NaN           ACC    Metabolite
# 2          NaN            ET    Metabolite
# 3          NaN          Cu2+    Metabolite
# 4          NaN           ETR   PlantCoding
#
# [5 rows x 40 columns]

# %%
def get_orthologues(x, prefix=""):
    id_, level_, label_ = x.values
    ########################
    # Specie specific homologues
    ########################
    
    return_D = {f"{prefix}_{specie}_homologues":"" for specie in all_species}
    
    if label_ in ['PlantCoding', 'PlantNonCoding',  'PlantAbstract']:

        for species in all_species:
            species = f"{species}_homologues"
            k = f"{prefix}_{species}"
            if level_ == 'node':
                return_D[k] = node_ids_key[species][id_]
            elif level_ == 'clade':
                return_D[k] =  clade_ids_key[species][id_]
            elif level_ == 'family':
                return_D[k] =  family_ids_key[species][id_]

    return_D = {x:helpers.list_to_string(list(return_D[x])) for x in return_D}
    return return_D

# %%
new_dfs = []
for prefix in ['input1', 'input2', 'input3', 'output1']:
    print(prefix)
    id_col, level_col, new_label_col  =\
                [prefix + x for x in ('_ID',  '_level',  '_label')]        
    
    new_df = df_edges[[id_col, level_col, new_label_col ]].apply(get_orthologues, axis=1, result_type='expand', prefix=prefix)
    new_dfs.append(new_df)
    #df_edges = df_edges.join(new_df, sort=False)
# Out:
# input1
# input2
# input3
# output1

# %%
homologues_df = pd.concat(new_dfs, sort=False, axis=1)

# %%
homologues_df.loc[0]
# Out:
# input1_ath_homologues
# input1_osa_homologues
# input1_stu_homologues
# input2_ath_homologues     AT2G36880,AT1G02500,AT4G01850,AT3G17390
# input2_osa_homologues
# input2_stu_homologues
# input3_ath_homologues
# input3_osa_homologues
# input3_stu_homologues
# output1_ath_homologues
# output1_osa_homologues
# output1_stu_homologues
# Name: 0, dtype: object

# %%
df_edges = df_edges.join(homologues_df, sort=False)

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input1_stu_homologues                              input2_ath_homologues  \
# 0                                  AT2G36880,AT1G02500,AT4G01850,AT3G17390
# 1                        AT5G65800,AT5G51690,AT4G26200,AT3G49700,AT1G01...
# 2                        AT1G62380,AT1G12010,AT1G77330,AT1G05010,AT2G19590
# 3                                  AT5G44790,AT5G21930,AT4G33520,AT1G63440
# 4
#
#   input2_osa_homologues input2_stu_homologues input3_ath_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#   input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT2G40940,AT1G66340,AT3G23150,AT1G04310,AT3G04580
#
#   output1_stu_homologues
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 52 columns]

# %%
node_type_to_node_form_dict = {
    "gene":"gene",
    
    "protein":"protein",
    "protein [activated]":"protein_active",
    'protein [active]': "protein_active",
    
    "ncRNA":"ncRNA",
    "plant_ncRNA":"ncRNA",
    'ta-siRNA':"ta-siRNA", 
        
    "complex":"complex", 
    "plant_complex":"complex",
    'complex [active]': "complex_active",
    
    "metabolite":"metabolite",
    
    "process":"process", 
    'process [active]':"process_active",

    np.nan:"", 
    "plant_coding":"unknown"
}

for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, new_form_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_form')]
    
    x = df_edges[[id_col, type_col]].dropna(how='all')
    
    print(prefix)
    df_edges[new_form_col] = df_edges[type_col].apply(lambda x: node_type_to_node_form_dict[x])
# Out:
# input1
# input2
# input3
# output1

# %%
df_edges.head()
# Out:
#   AddedBy   ConnID Species input1_ID input1_level input1_localisation  \
# 0      KG  Conn001     ath     L-Met       family                  ER
# 1      KG  Conn002     ath      SAMe       family                  ER
# 2      KG  Conn003     ath       ACC       family                  ER
# 3      KG  Conn004     ath      Cu2+       family           cytoplasm
# 4      KG  Conn005     ath       ETR       family                  ER
#
#   input1_type input2_ID input2_level input2_localisation  ...  \
# 0  metabolite      SAMS        clade                  ER  ...
# 1  metabolite       ACS       family                  ER  ...
# 2  metabolite       ACO       family                  ER  ...
# 3  metabolite       HMA       family                  ER  ...
# 4     protein      Cu2+       family                  ER  ...
#
#   input3_ath_homologues input3_osa_homologues input3_stu_homologues  \
# 0
# 1
# 2
# 3
# 4
#
#                               output1_ath_homologues output1_osa_homologues  \
# 0
# 1
# 2
# 3
# 4  AT2G40940,AT1G66340,AT3G23150,AT1G04310,AT3G04580
#
#   output1_stu_homologues input1_form     input2_form input3_form  \
# 0                         metabolite  protein_active
# 1                         metabolite  protein_active
# 2                         metabolite  protein_active
# 3                         metabolite         protein
# 4                            protein      metabolite
#
#      output1_form
# 0      metabolite
# 1      metabolite
# 2      metabolite
# 3      metabolite
# 4  protein_active
#
# [5 rows x 56 columns]

# %%
node_localisation_dict = {
    'nuc':'nucleus',
    'er':'endoplasmic reticulum',
    'golgi':'golgi apparatus'
}


good_localisations = set([
     'nucleus',
     'nucleolus',
     'cytoplasm',
     'vacuole',
     'endoplasmic reticulum',
     'chloroplast',
     'mitochondrion',
     'golgi apparatus',
     'peroxisome',
     'apoplast',
     'extracellular'
])


def node_localisation_std(x):
    if not type(x) == str:
        return ""
    
    x = x.lower()
    if x in node_localisation_dict.keys():
        x = node_localisation_dict[x]
    
    if x in good_localisations:
        return x
    else:
        return ""

node_localisations = set()
new_localisation = set()
for prefix in ['input1', 'input2', 'input3', 'output1']:
    id_col, type_col, localisation_col  =\
        [prefix + x for x in ('_ID',  '_type',  '_localisation')]
    
    x = df_edges[['ConnID', id_col, localisation_col]].dropna(how='all', subset=[ id_col, localisation_col])
    
    #for _, y in x.iterrows():
    #    if y[localisation_col] in ['mitochondria?', np.nan]:
    #        print(y['ConnID'], "\t", y[id_col], "\t", y[localisation_col])
    
    
    node_localisations.update(x[localisation_col])
    
    #print(prefix)
    df_edges[localisation_col] = df_edges[localisation_col].apply(node_localisation_std)
    
    new_localisation.update(df_edges[localisation_col])

# %%
node_localisations
# Out:
# {'ER',
#  'Golgi',
#  'chloroplast',
#  'cytoplasm',
#  'extracellular',
#  'mitochondria?',
#  nan,
#  'nuc',
#  'nucleus',
#  'peroxisome',
#  'vacuole'}

# %%
new_localisation
# Out:
# {'',
#  'chloroplast',
#  'cytoplasm',
#  'endoplasmic reticulum',
#  'extracellular',
#  'golgi apparatus',
#  'nucleus',
#  'peroxisome',
#  'vacuole'}

# %%
df_edges.to_csv(os.path.join("..", "data", "raw", "edges-sheet.tsv"), sep="\t")

# %%
homologue_cols = [f"{x}_homologues" for x in all_species]

# %%
all_species
# Out:
# ['ath', 'stu', 'osa']

# %%
with open(os.path.join("..", "data", "raw", "complexes_to_add.tsv"), "w") as out:
    for c in complexes_to_add:
        out.write(f"{c}\n")
